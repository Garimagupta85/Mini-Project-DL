# %%
# !pwd
# Out:
# /home/studio-lab-user/sagemaker-studiolab-notebooks

# %%
# !ls
# Out:
# 'Getting Started.ipynb'        model0.5832674050632911.pth
# 'Untitled Folder'	       model0.6991693037974683.pth
#  __pycache__		       model0.7150909810126582.pth
#  checkpoint		       model0.7544501582278481.pth
#  data			       model0.7929193037974683.pth
#  dataset.py		       new-workspace.jupyterlab-workspace
#  images			       runs
#  model.py		       test.ipynb
#  model.txt		       train.py
#  model0.5375791139240507.pth   utils.py
#  model0.5387658227848101.pth   vis.py

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.13.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.5.0)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: torch==1.13.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: typing-extensions in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torchvision) (1.23.4)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.10.3.66)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.37.1)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (65.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->torchvision) (2.1.1)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import argparse

# %%
import torch.utils.data as data

# %%
import time
import sys

# %%
import os
import os
import sys
import time
import math

import torch.nn as nn
import torch.nn.init as init
#_, term_width = os.popen('stty size', 'r').read().split()
#term_width = int(term_width)

# %%
def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
#from utils import progress_bar

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time
def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
start_epoch = 0
best_acc = 0

# %%
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
# Out:
# ==> Preparing data..

# %%
trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
# Out:
# Files already downloaded and verified

# %%
trainset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(trainset) * VALID_RATIO)
n_valid_examples = len(trainset) - n_train_examples

train_data, valid_data = data.random_split(trainset, 
                                           [n_train_examples, n_valid_examples])

# %%
train_data

# %%
valid_data

# %%
trainset=train_data

# %%
valset = valid_data

# %%
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

# %%
valloader = torch.utils.data.DataLoader(
    valset, batch_size=128, shuffle=True, num_workers=2)

# %%
testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
# Out:
# Files already downloaded and verified

# %%
testset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %%
## model to use
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        """
        in_planes: C_in for conv1 and Sequential.Conv2d
        planes: F_i
        """
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3, stride=stride, padding=1, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks,  num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32
        """
        in_planes: C_out of layer1
        """
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=1)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
            """
            in_planes becomes the output of the current layer
            """
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 32) # to be understood
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
print('==> Building model..')
net = ResNet18()
net = net.to(device)
# Out:
# ==> Building model..

# %%
# !pip install torch-summary
# Out:
# Requirement already satisfied: torch-summary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.4.5)

# %%
#original model only for reference
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)  # same as the last layer's HxW
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
originalNet = ResNet18()
summary(originalNet, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
## For our model
from torchsummary import summary
summary(net, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#             Conv2d-3           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-4           [-1, 32, 32, 32]              64
#             Conv2d-5           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#         BasicBlock-7           [-1, 32, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#            Conv2d-10           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-11           [-1, 32, 32, 32]              64
#        BasicBlock-12           [-1, 32, 32, 32]               0
#            Conv2d-13           [-1, 64, 32, 32]          18,432
#       BatchNorm2d-14           [-1, 64, 32, 32]             128
#            Conv2d-15           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-16           [-1, 64, 32, 32]             128
#            Conv2d-17           [-1, 64, 32, 32]          18,432
#       BatchNorm2d-18           [-1, 64, 32, 32]             128
#        BasicBlock-19           [-1, 64, 32, 32]               0
#            Conv2d-20           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-21           [-1, 64, 32, 32]             128
#            Conv2d-22           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-23           [-1, 64, 32, 32]             128
#        BasicBlock-24           [-1, 64, 32, 32]               0
#            Conv2d-25          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-26          [-1, 128, 32, 32]             256
#            Conv2d-27          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-28          [-1, 128, 32, 32]             256
#            Conv2d-29          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-30          [-1, 128, 32, 32]             256
#        BasicBlock-31          [-1, 128, 32, 32]               0
#            Conv2d-32          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-33          [-1, 128, 32, 32]             256
#            Conv2d-34          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-35          [-1, 128, 32, 32]             256
#        BasicBlock-36          [-1, 128, 32, 32]               0
#            Conv2d-37          [-1, 256, 32, 32]         294,912
#       BatchNorm2d-38          [-1, 256, 32, 32]             512
#            Conv2d-39          [-1, 256, 32, 32]         589,824
#       BatchNorm2d-40          [-1, 256, 32, 32]             512
#            Conv2d-41          [-1, 256, 32, 32]         294,912
#       BatchNorm2d-42          [-1, 256, 32, 32]             512
#        BasicBlock-43          [-1, 256, 32, 32]               0
#            Conv2d-44          [-1, 256, 32, 32]         589,824
#       BatchNorm2d-45          [-1, 256, 32, 32]             512
#            Conv2d-46          [-1, 256, 32, 32]         589,824
#       BatchNorm2d-47          [-1, 256, 32, 32]             512
#        BasicBlock-48          [-1, 256, 32, 32]               0
#            Linear-49                   [-1, 10]           2,570
# ================================================================
# Total params: 3,141,674
# Trainable params: 3,141,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 45.00
# Params size (MB): 11.98
# Estimated Total Size (MB): 57.00
# ----------------------------------------------------------------

# %%
device
# Out:
# 'cuda'

# %%
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# %%
resume = False
if resume == True:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
    checkpoint = torch.load('./checkpoint/ckpt.pth')
    net.load_state_dict(checkpoint['net'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch']

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.0001,
                      momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (4.64.1)

# %%
from tqdm import tqdm

# %%
len(trainloader)
# Out:
# 352

# %%
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    steps = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        steps = steps+1
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        #progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
        #             % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
        if steps%87==0:
            print(f"Epoch:{epoch} --Progress(%):{batch_idx/len(trainloader)*100.:.2f}-- Loss:{train_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")

# %%
def val(epoch):
    global best_acc
    net.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            #progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            #             % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print(f"Epoch:{epoch} --Val Loss:{val_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")
            
    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving the best model.')
        #state = {
        #    'net': net.state_dict(),
        #    'acc': acc,
        #    'epoch': epoch,
        #}
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        #torch.save(state, './checkpoint/ckpt.pth')
        
        torch.save(net.state_dict(), './checkpoint/ckpt.pth')
        best_acc = acc

# %%
def test(epoch):
    print("***** Begin testing *****")
    net.load_state_dict(torch.load('./checkpoint/ckpt.pth'))
    net.eval()
    
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            #progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            #             % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print(f"Epoch:{epoch} --Test Loss:{test_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")

# %%
for epoch in range(start_epoch, start_epoch+100):
    train(epoch)
    scheduler.step()
    val(epoch)
    
test(epoch)
# Out:
# Epoch: 0
# Epoch:0 --Progress(%):24.43-- Loss:2.15 -- Acc:19.48
# Epoch:0 --Progress(%):49.15-- Loss:2.11 -- Acc:21.36
# Epoch:0 --Progress(%):73.86-- Loss:2.08 -- Acc:22.61
# Epoch:0 --Progress(%):98.58-- Loss:2.05 -- Acc:24.10
# Epoch:0 --Val Loss:1.93 -- Acc:28.94
# Saving the best model.
#
# Epoch: 1
# Epoch:1 --Progress(%):24.43-- Loss:1.90 -- Acc:29.55
# Epoch:1 --Progress(%):49.15-- Loss:1.88 -- Acc:30.39
# Epoch:1 --Progress(%):73.86-- Loss:1.87 -- Acc:30.77
# Epoch:1 --Progress(%):98.58-- Loss:1.85 -- Acc:31.30
# Epoch:1 --Val Loss:1.78 -- Acc:34.12
# Saving the best model.
#
# Epoch: 2
# Epoch:2 --Progress(%):24.43-- Loss:1.78 -- Acc:33.77
# Epoch:2 --Progress(%):49.15-- Loss:1.76 -- Acc:34.51
# Epoch:2 --Progress(%):73.86-- Loss:1.75 -- Acc:35.04
# Epoch:2 --Progress(%):98.58-- Loss:1.74 -- Acc:35.39
# Epoch:2 --Val Loss:1.70 -- Acc:36.58
# Saving the best model.
#
# Epoch: 3
# Epoch:3 --Progress(%):24.43-- Loss:1.69 -- Acc:37.11
# Epoch:3 --Progress(%):49.15-- Loss:1.68 -- Acc:37.44
# Epoch:3 --Progress(%):73.86-- Loss:1.67 -- Acc:38.04
# Epoch:3 --Progress(%):98.58-- Loss:1.66 -- Acc:38.37
# Epoch:3 --Val Loss:1.63 -- Acc:39.18
# Saving the best model.
#
# Epoch: 4
# Epoch:4 --Progress(%):24.43-- Loss:1.62 -- Acc:40.10
# Epoch:4 --Progress(%):49.15-- Loss:1.61 -- Acc:40.19
# Epoch:4 --Progress(%):73.86-- Loss:1.60 -- Acc:40.75
# Epoch:4 --Progress(%):98.58-- Loss:1.59 -- Acc:40.98
# Epoch:4 --Val Loss:1.58 -- Acc:43.02
# Saving the best model.
#
# Epoch: 5
# Epoch:5 --Progress(%):24.43-- Loss:1.56 -- Acc:41.99
# Epoch:5 --Progress(%):49.15-- Loss:1.55 -- Acc:42.34
# Epoch:5 --Progress(%):73.86-- Loss:1.55 -- Acc:42.63
# Epoch:5 --Progress(%):98.58-- Loss:1.54 -- Acc:42.96
# Epoch:5 --Val Loss:1.51 -- Acc:44.80
# Saving the best model.
#
# Epoch: 6
# Epoch:6 --Progress(%):24.43-- Loss:1.50 -- Acc:44.35
# Epoch:6 --Progress(%):49.15-- Loss:1.49 -- Acc:44.57
# Epoch:6 --Progress(%):73.86-- Loss:1.49 -- Acc:44.69
# Epoch:6 --Progress(%):98.58-- Loss:1.49 -- Acc:44.92
# Epoch:6 --Val Loss:1.48 -- Acc:46.32
# Saving the best model.
#
# Epoch: 7
# Epoch:7 --Progress(%):24.43-- Loss:1.46 -- Acc:46.70
# Epoch:7 --Progress(%):49.15-- Loss:1.45 -- Acc:46.62
# Epoch:7 --Progress(%):73.86-- Loss:1.45 -- Acc:46.72
# Epoch:7 --Progress(%):98.58-- Loss:1.44 -- Acc:46.89
# Epoch:7 --Val Loss:1.42 -- Acc:48.64
# Saving the best model.
#
# Epoch: 8
# Epoch:8 --Progress(%):24.43-- Loss:1.42 -- Acc:48.17
# Epoch:8 --Progress(%):49.15-- Loss:1.42 -- Acc:48.06
# Epoch:8 --Progress(%):73.86-- Loss:1.41 -- Acc:48.47
# Epoch:8 --Progress(%):98.58-- Loss:1.40 -- Acc:48.76
# Epoch:8 --Val Loss:1.41 -- Acc:49.00
# Saving the best model.
#
# Epoch: 9
# Epoch:9 --Progress(%):24.43-- Loss:1.38 -- Acc:48.94
# Epoch:9 --Progress(%):49.15-- Loss:1.37 -- Acc:49.21
# Epoch:9 --Progress(%):73.86-- Loss:1.37 -- Acc:49.49
# Epoch:9 --Progress(%):98.58-- Loss:1.36 -- Acc:49.78
# Epoch:9 --Val Loss:1.37 -- Acc:50.30
# Saving the best model.
#
# Epoch: 10
# Epoch:10 --Progress(%):24.43-- Loss:1.33 -- Acc:51.89
# Epoch:10 --Progress(%):49.15-- Loss:1.33 -- Acc:51.80
# Epoch:10 --Progress(%):73.86-- Loss:1.33 -- Acc:51.64
# Epoch:10 --Progress(%):98.58-- Loss:1.32 -- Acc:51.88
# Epoch:10 --Val Loss:1.33 -- Acc:52.86
# Saving the best model.
#
# Epoch: 11
# Epoch:11 --Progress(%):24.43-- Loss:1.29 -- Acc:53.04
# Epoch:11 --Progress(%):49.15-- Loss:1.30 -- Acc:52.90
# Epoch:11 --Progress(%):73.86-- Loss:1.29 -- Acc:53.26
# Epoch:11 --Progress(%):98.58-- Loss:1.29 -- Acc:53.40
# Epoch:11 --Val Loss:1.29 -- Acc:53.44
# Saving the best model.
#
# Epoch: 12
# Epoch:12 --Progress(%):24.43-- Loss:1.25 -- Acc:54.24
# Epoch:12 --Progress(%):49.15-- Loss:1.26 -- Acc:54.06
# Epoch:12 --Progress(%):73.86-- Loss:1.26 -- Acc:53.99
# Epoch:12 --Progress(%):98.58-- Loss:1.26 -- Acc:54.20
# Epoch:12 --Val Loss:1.25 -- Acc:55.00
# Saving the best model.
#
# Epoch: 13
# Epoch:13 --Progress(%):24.43-- Loss:1.23 -- Acc:55.53
# Epoch:13 --Progress(%):49.15-- Loss:1.23 -- Acc:55.38
# Epoch:13 --Progress(%):73.86-- Loss:1.23 -- Acc:55.42
# Epoch:13 --Progress(%):98.58-- Loss:1.22 -- Acc:55.74
# Epoch:13 --Val Loss:1.21 -- Acc:55.40
# Saving the best model.
#
# Epoch: 14
# Epoch:14 --Progress(%):24.43-- Loss:1.20 -- Acc:56.21
# Epoch:14 --Progress(%):49.15-- Loss:1.20 -- Acc:56.57
# Epoch:14 --Progress(%):73.86-- Loss:1.20 -- Acc:56.49
# Epoch:14 --Progress(%):98.58-- Loss:1.19 -- Acc:56.67
# Epoch:14 --Val Loss:1.21 -- Acc:56.20
# Saving the best model.
#
# Epoch: 15
# Epoch:15 --Progress(%):24.43-- Loss:1.18 -- Acc:57.28
# Epoch:15 --Progress(%):49.15-- Loss:1.17 -- Acc:57.62
# Epoch:15 --Progress(%):73.86-- Loss:1.17 -- Acc:57.76
# Epoch:15 --Progress(%):98.58-- Loss:1.16 -- Acc:57.89
# Epoch:15 --Val Loss:1.16 -- Acc:57.94
# Saving the best model.
#
# Epoch: 16
# Epoch:16 --Progress(%):24.43-- Loss:1.14 -- Acc:58.69
# Epoch:16 --Progress(%):49.15-- Loss:1.14 -- Acc:58.85
# Epoch:16 --Progress(%):73.86-- Loss:1.14 -- Acc:58.70
# Epoch:16 --Progress(%):98.58-- Loss:1.14 -- Acc:58.76
# Epoch:16 --Val Loss:1.14 -- Acc:59.06
# Saving the best model.
#
# Epoch: 17
# Epoch:17 --Progress(%):24.43-- Loss:1.13 -- Acc:58.93
# Epoch:17 --Progress(%):49.15-- Loss:1.13 -- Acc:59.27
# Epoch:17 --Progress(%):73.86-- Loss:1.12 -- Acc:59.46
# Epoch:17 --Progress(%):98.58-- Loss:1.12 -- Acc:59.72
# Epoch:17 --Val Loss:1.14 -- Acc:59.12
# Saving the best model.
#
# Epoch: 18
# Epoch:18 --Progress(%):24.43-- Loss:1.09 -- Acc:60.56
# Epoch:18 --Progress(%):49.15-- Loss:1.09 -- Acc:60.45
# Epoch:18 --Progress(%):73.86-- Loss:1.09 -- Acc:60.58
# Epoch:18 --Progress(%):98.58-- Loss:1.09 -- Acc:60.54
# Epoch:18 --Val Loss:1.11 -- Acc:60.26
# Saving the best model.
#
# Epoch: 19
# Epoch:19 --Progress(%):24.43-- Loss:1.07 -- Acc:61.38
# Epoch:19 --Progress(%):49.15-- Loss:1.07 -- Acc:61.28
# Epoch:19 --Progress(%):73.86-- Loss:1.07 -- Acc:61.28
# Epoch:19 --Progress(%):98.58-- Loss:1.07 -- Acc:61.32
# Epoch:19 --Val Loss:1.08 -- Acc:60.72
# Saving the best model.
#
# Epoch: 20
# Epoch:20 --Progress(%):24.43-- Loss:1.05 -- Acc:61.97
# Epoch:20 --Progress(%):49.15-- Loss:1.05 -- Acc:62.16
# Epoch:20 --Progress(%):73.86-- Loss:1.05 -- Acc:61.90
# Epoch:20 --Progress(%):98.58-- Loss:1.05 -- Acc:62.02
# Epoch:20 --Val Loss:1.06 -- Acc:61.90
# Saving the best model.
#
# Epoch: 21
# Epoch:21 --Progress(%):24.43-- Loss:1.03 -- Acc:63.10
# Epoch:21 --Progress(%):49.15-- Loss:1.03 -- Acc:62.79
# Epoch:21 --Progress(%):73.86-- Loss:1.03 -- Acc:62.62
# Epoch:21 --Progress(%):98.58-- Loss:1.03 -- Acc:62.82
# Epoch:21 --Val Loss:1.05 -- Acc:62.40
# Saving the best model.
#
# Epoch: 22
# Epoch:22 --Progress(%):24.43-- Loss:1.02 -- Acc:63.33
# Epoch:22 --Progress(%):49.15-- Loss:1.02 -- Acc:63.27
# Epoch:22 --Progress(%):73.86-- Loss:1.01 -- Acc:63.69
# Epoch:22 --Progress(%):98.58-- Loss:1.02 -- Acc:63.57
# Epoch:22 --Val Loss:1.03 -- Acc:62.24
#
# Epoch: 23
# Epoch:23 --Progress(%):24.43-- Loss:0.99 -- Acc:64.47
# Epoch:23 --Progress(%):49.15-- Loss:1.00 -- Acc:64.39
# Epoch:23 --Progress(%):73.86-- Loss:1.00 -- Acc:64.12
# Epoch:23 --Progress(%):98.58-- Loss:1.00 -- Acc:64.00
# Epoch:23 --Val Loss:1.01 -- Acc:63.12
# Saving the best model.
#
# Epoch: 24
# Epoch:24 --Progress(%):24.43-- Loss:0.99 -- Acc:64.86
# Epoch:24 --Progress(%):49.15-- Loss:1.00 -- Acc:64.34
# Epoch:24 --Progress(%):73.86-- Loss:0.99 -- Acc:64.37
# Epoch:24 --Progress(%):98.58-- Loss:0.99 -- Acc:64.61
# Epoch:24 --Val Loss:0.97 -- Acc:64.60
# Saving the best model.
#
# Epoch: 25
# Epoch:25 --Progress(%):24.43-- Loss:0.98 -- Acc:64.79
# Epoch:25 --Progress(%):49.15-- Loss:0.97 -- Acc:65.04
# Epoch:25 --Progress(%):73.86-- Loss:0.97 -- Acc:65.05
# Epoch:25 --Progress(%):98.58-- Loss:0.97 -- Acc:65.04
# Epoch:25 --Val Loss:0.97 -- Acc:64.56
#
# Epoch: 26
# Epoch:26 --Progress(%):24.43-- Loss:0.95 -- Acc:65.84
# Epoch:26 --Progress(%):49.15-- Loss:0.95 -- Acc:65.88
# Epoch:26 --Progress(%):73.86-- Loss:0.95 -- Acc:65.94
# Epoch:26 --Progress(%):98.58-- Loss:0.95 -- Acc:65.83
# Epoch:26 --Val Loss:0.99 -- Acc:64.36
#
# Epoch: 27
# Epoch:27 --Progress(%):24.43-- Loss:0.93 -- Acc:66.49
# Epoch:27 --Progress(%):49.15-- Loss:0.94 -- Acc:66.48
# Epoch:27 --Progress(%):73.86-- Loss:0.94 -- Acc:66.30
# Epoch:27 --Progress(%):98.58-- Loss:0.94 -- Acc:66.17
# Epoch:27 --Val Loss:0.97 -- Acc:65.08
# Saving the best model.
#
# Epoch: 28
# Epoch:28 --Progress(%):24.43-- Loss:0.93 -- Acc:66.80
# Epoch:28 --Progress(%):49.15-- Loss:0.93 -- Acc:66.55
# Epoch:28 --Progress(%):73.86-- Loss:0.92 -- Acc:66.83
# Epoch:28 --Progress(%):98.58-- Loss:0.92 -- Acc:66.80
# Epoch:28 --Val Loss:0.94 -- Acc:66.20
# Saving the best model.
#
# Epoch: 29
# Epoch:29 --Progress(%):24.43-- Loss:0.91 -- Acc:66.77
# Epoch:29 --Progress(%):49.15-- Loss:0.92 -- Acc:67.04
# Epoch:29 --Progress(%):73.86-- Loss:0.92 -- Acc:67.09
# Epoch:29 --Progress(%):98.58-- Loss:0.92 -- Acc:67.11
# Epoch:29 --Val Loss:0.92 -- Acc:66.48
# Saving the best model.
#
# Epoch: 30
# Epoch:30 --Progress(%):24.43-- Loss:0.91 -- Acc:67.56
# Epoch:30 --Progress(%):49.15-- Loss:0.91 -- Acc:67.51
# Epoch:30 --Progress(%):73.86-- Loss:0.91 -- Acc:67.56
# Epoch:30 --Progress(%):98.58-- Loss:0.90 -- Acc:67.73
# Epoch:30 --Val Loss:0.92 -- Acc:66.66
# Saving the best model.
#
# Epoch: 31
# Epoch:31 --Progress(%):24.43-- Loss:0.87 -- Acc:68.68
# Epoch:31 --Progress(%):49.15-- Loss:0.88 -- Acc:68.64
# Epoch:31 --Progress(%):73.86-- Loss:0.89 -- Acc:68.29
# Epoch:31 --Progress(%):98.58-- Loss:0.89 -- Acc:68.20
# Epoch:31 --Val Loss:0.91 -- Acc:67.22
# Saving the best model.
#
# Epoch: 32
# Epoch:32 --Progress(%):24.43-- Loss:0.89 -- Acc:68.35
# Epoch:32 --Progress(%):49.15-- Loss:0.89 -- Acc:68.51
# Epoch:32 --Progress(%):73.86-- Loss:0.88 -- Acc:68.48
# Epoch:32 --Progress(%):98.58-- Loss:0.88 -- Acc:68.45
# Epoch:32 --Val Loss:0.92 -- Acc:67.02
#
# Epoch: 33
# Epoch:33 --Progress(%):24.43-- Loss:0.87 -- Acc:68.59
# Epoch:33 --Progress(%):49.15-- Loss:0.87 -- Acc:68.91
# Epoch:33 --Progress(%):73.86-- Loss:0.86 -- Acc:69.19
# Epoch:33 --Progress(%):98.58-- Loss:0.87 -- Acc:68.97
# Epoch:33 --Val Loss:0.90 -- Acc:67.20
#
# Epoch: 34
# Epoch:34 --Progress(%):24.43-- Loss:0.86 -- Acc:69.09
# Epoch:34 --Progress(%):49.15-- Loss:0.85 -- Acc:69.28
# Epoch:34 --Progress(%):73.86-- Loss:0.85 -- Acc:69.36
# Epoch:34 --Progress(%):98.58-- Loss:0.85 -- Acc:69.39
# Epoch:34 --Val Loss:0.89 -- Acc:68.34
# Saving the best model.
#
# Epoch: 35
# Epoch:35 --Progress(%):24.43-- Loss:0.83 -- Acc:70.28
# Epoch:35 --Progress(%):49.15-- Loss:0.85 -- Acc:69.72
# Epoch:35 --Progress(%):73.86-- Loss:0.84 -- Acc:69.88
# Epoch:35 --Progress(%):98.58-- Loss:0.85 -- Acc:69.75
# Epoch:35 --Val Loss:0.87 -- Acc:69.26
# Saving the best model.
#
# Epoch: 36
# Epoch:36 --Progress(%):24.43-- Loss:0.84 -- Acc:69.81
# Epoch:36 --Progress(%):49.15-- Loss:0.84 -- Acc:70.00
# Epoch:36 --Progress(%):73.86-- Loss:0.83 -- Acc:70.18
# Epoch:36 --Progress(%):98.58-- Loss:0.83 -- Acc:70.23
# Epoch:36 --Val Loss:0.88 -- Acc:68.96
#
# Epoch: 37
# Epoch:37 --Progress(%):24.43-- Loss:0.83 -- Acc:70.79
# Epoch:37 --Progress(%):49.15-- Loss:0.83 -- Acc:70.61
# Epoch:37 --Progress(%):73.86-- Loss:0.82 -- Acc:70.52
# Epoch:37 --Progress(%):98.58-- Loss:0.82 -- Acc:70.62
# Epoch:37 --Val Loss:0.87 -- Acc:69.30
# Saving the best model.
#
# Epoch: 38
# Epoch:38 --Progress(%):24.43-- Loss:0.80 -- Acc:71.05
# Epoch:38 --Progress(%):49.15-- Loss:0.80 -- Acc:71.18
# Epoch:38 --Progress(%):73.86-- Loss:0.81 -- Acc:71.10
# Epoch:38 --Progress(%):98.58-- Loss:0.82 -- Acc:70.85
# Epoch:38 --Val Loss:0.86 -- Acc:69.00
#
# Epoch: 39
# Epoch:39 --Progress(%):24.43-- Loss:0.83 -- Acc:70.56
# Epoch:39 --Progress(%):49.15-- Loss:0.82 -- Acc:70.89
# Epoch:39 --Progress(%):73.86-- Loss:0.81 -- Acc:71.14
# Epoch:39 --Progress(%):98.58-- Loss:0.81 -- Acc:71.13
# Epoch:39 --Val Loss:0.83 -- Acc:69.80
# Saving the best model.
#
# Epoch: 40
# Epoch:40 --Progress(%):24.43-- Loss:0.80 -- Acc:71.25
# Epoch:40 --Progress(%):49.15-- Loss:0.80 -- Acc:71.33
# Epoch:40 --Progress(%):73.86-- Loss:0.80 -- Acc:71.40
# Epoch:40 --Progress(%):98.58-- Loss:0.80 -- Acc:71.56
# Epoch:40 --Val Loss:0.82 -- Acc:70.90
# Saving the best model.
#
# Epoch: 41
# Epoch:41 --Progress(%):24.43-- Loss:0.79 -- Acc:71.68
# Epoch:41 --Progress(%):49.15-- Loss:0.79 -- Acc:71.48
# Epoch:41 --Progress(%):73.86-- Loss:0.79 -- Acc:71.70
# Epoch:41 --Progress(%):98.58-- Loss:0.79 -- Acc:71.80
# Epoch:41 --Val Loss:0.81 -- Acc:70.26
#
# Epoch: 42
# Epoch:42 --Progress(%):24.43-- Loss:0.79 -- Acc:72.10
# Epoch:42 --Progress(%):49.15-- Loss:0.78 -- Acc:72.41
# Epoch:42 --Progress(%):73.86-- Loss:0.78 -- Acc:72.25
# Epoch:42 --Progress(%):98.58-- Loss:0.78 -- Acc:72.20
# Epoch:42 --Val Loss:0.81 -- Acc:70.12
#
# Epoch: 43
# Epoch:43 --Progress(%):24.43-- Loss:0.78 -- Acc:72.34
# Epoch:43 --Progress(%):49.15-- Loss:0.78 -- Acc:72.46
# Epoch:43 --Progress(%):73.86-- Loss:0.78 -- Acc:72.34
# Epoch:43 --Progress(%):98.58-- Loss:0.77 -- Acc:72.39
# Epoch:43 --Val Loss:0.82 -- Acc:70.56
#
# Epoch: 44
# Epoch:44 --Progress(%):24.43-- Loss:0.76 -- Acc:73.20
# Epoch:44 --Progress(%):49.15-- Loss:0.76 -- Acc:73.24
# Epoch:44 --Progress(%):73.86-- Loss:0.76 -- Acc:72.99
# Epoch:44 --Progress(%):98.58-- Loss:0.76 -- Acc:72.97
# Epoch:44 --Val Loss:0.81 -- Acc:71.60
# Saving the best model.
#
# Epoch: 45
# Epoch:45 --Progress(%):24.43-- Loss:0.76 -- Acc:72.86
# Epoch:45 --Progress(%):49.15-- Loss:0.77 -- Acc:72.73
# Epoch:45 --Progress(%):73.86-- Loss:0.76 -- Acc:72.76
# Epoch:45 --Progress(%):98.58-- Loss:0.76 -- Acc:73.00
# Epoch:45 --Val Loss:0.81 -- Acc:71.72
# Saving the best model.
#
# Epoch: 46
# Epoch:46 --Progress(%):24.43-- Loss:0.75 -- Acc:73.05
# Epoch:46 --Progress(%):49.15-- Loss:0.75 -- Acc:72.97
# Epoch:46 --Progress(%):73.86-- Loss:0.75 -- Acc:73.18
# Epoch:46 --Progress(%):98.58-- Loss:0.75 -- Acc:73.32
# Epoch:46 --Val Loss:0.78 -- Acc:71.46
#
# Epoch: 47
# Epoch:47 --Progress(%):24.43-- Loss:0.76 -- Acc:72.47
# Epoch:47 --Progress(%):49.15-- Loss:0.75 -- Acc:73.07
# Epoch:47 --Progress(%):73.86-- Loss:0.74 -- Acc:73.28
# Epoch:47 --Progress(%):98.58-- Loss:0.74 -- Acc:73.56
# Epoch:47 --Val Loss:0.77 -- Acc:71.60
#
# Epoch: 48
# Epoch:48 --Progress(%):24.43-- Loss:0.73 -- Acc:73.89
# Epoch:48 --Progress(%):49.15-- Loss:0.73 -- Acc:73.82
# Epoch:48 --Progress(%):73.86-- Loss:0.73 -- Acc:74.09
# Epoch:48 --Progress(%):98.58-- Loss:0.73 -- Acc:73.86
# Epoch:48 --Val Loss:0.78 -- Acc:71.46
#
# Epoch: 49
# Epoch:49 --Progress(%):24.43-- Loss:0.72 -- Acc:74.25
# Epoch:49 --Progress(%):49.15-- Loss:0.72 -- Acc:74.19
# Epoch:49 --Progress(%):73.86-- Loss:0.73 -- Acc:74.16
# Epoch:49 --Progress(%):98.58-- Loss:0.73 -- Acc:74.13
# Epoch:49 --Val Loss:0.77 -- Acc:72.00
# Saving the best model.
#
# Epoch: 50
# Epoch:50 --Progress(%):24.43-- Loss:0.72 -- Acc:74.33
# Epoch:50 --Progress(%):49.15-- Loss:0.72 -- Acc:74.19
# Epoch:50 --Progress(%):73.86-- Loss:0.72 -- Acc:74.38
# Epoch:50 --Progress(%):98.58-- Loss:0.72 -- Acc:74.44
# Epoch:50 --Val Loss:0.76 -- Acc:72.34
# Saving the best model.
#
# Epoch: 51
# Epoch:51 --Progress(%):24.43-- Loss:0.70 -- Acc:74.68
# Epoch:51 --Progress(%):49.15-- Loss:0.71 -- Acc:74.52
# Epoch:51 --Progress(%):73.86-- Loss:0.71 -- Acc:74.57
# Epoch:51 --Progress(%):98.58-- Loss:0.71 -- Acc:74.56
# Epoch:51 --Val Loss:0.78 -- Acc:72.56
# Saving the best model.
#
# Epoch: 52
# Epoch:52 --Progress(%):24.43-- Loss:0.70 -- Acc:75.26
# Epoch:52 --Progress(%):49.15-- Loss:0.71 -- Acc:75.09
# Epoch:52 --Progress(%):73.86-- Loss:0.70 -- Acc:75.14
# Epoch:52 --Progress(%):98.58-- Loss:0.70 -- Acc:75.26
# Epoch:52 --Val Loss:0.75 -- Acc:73.50
# Saving the best model.
#
# Epoch: 53
# Epoch:53 --Progress(%):24.43-- Loss:0.69 -- Acc:75.13
# Epoch:53 --Progress(%):49.15-- Loss:0.70 -- Acc:75.05
# Epoch:53 --Progress(%):73.86-- Loss:0.70 -- Acc:75.34
# Epoch:53 --Progress(%):98.58-- Loss:0.70 -- Acc:75.41
# Epoch:53 --Val Loss:0.76 -- Acc:73.30
#
# Epoch: 54
# Epoch:54 --Progress(%):24.43-- Loss:0.68 -- Acc:75.52
# Epoch:54 --Progress(%):49.15-- Loss:0.69 -- Acc:75.56
# Epoch:54 --Progress(%):73.86-- Loss:0.69 -- Acc:75.56
# Epoch:54 --Progress(%):98.58-- Loss:0.69 -- Acc:75.47
# Epoch:54 --Val Loss:0.75 -- Acc:73.70
# Saving the best model.
#
# Epoch: 55
# Epoch:55 --Progress(%):24.43-- Loss:0.68 -- Acc:76.01
# Epoch:55 --Progress(%):49.15-- Loss:0.68 -- Acc:75.81
# Epoch:55 --Progress(%):73.86-- Loss:0.68 -- Acc:75.61
# Epoch:55 --Progress(%):98.58-- Loss:0.68 -- Acc:75.49
# Epoch:55 --Val Loss:0.75 -- Acc:73.82
# Saving the best model.
#
# Epoch: 56
# Epoch:56 --Progress(%):24.43-- Loss:0.68 -- Acc:76.14
# Epoch:56 --Progress(%):49.15-- Loss:0.68 -- Acc:76.19
# Epoch:56 --Progress(%):73.86-- Loss:0.68 -- Acc:75.80
# Epoch:56 --Progress(%):98.58-- Loss:0.68 -- Acc:76.13
# Epoch:56 --Val Loss:0.71 -- Acc:74.02
# Saving the best model.
#
# Epoch: 57
# Epoch:57 --Progress(%):24.43-- Loss:0.68 -- Acc:75.80
# Epoch:57 --Progress(%):49.15-- Loss:0.67 -- Acc:76.06
# Epoch:57 --Progress(%):73.86-- Loss:0.67 -- Acc:76.18
# Epoch:57 --Progress(%):98.58-- Loss:0.67 -- Acc:76.15
# Epoch:57 --Val Loss:0.76 -- Acc:73.56
#
# Epoch: 58
# Epoch:58 --Progress(%):24.43-- Loss:0.68 -- Acc:76.24
# Epoch:58 --Progress(%):49.15-- Loss:0.67 -- Acc:76.59
# Epoch:58 --Progress(%):73.86-- Loss:0.67 -- Acc:76.58
# Epoch:58 --Progress(%):98.58-- Loss:0.66 -- Acc:76.57
# Epoch:58 --Val Loss:0.73 -- Acc:74.70
# Saving the best model.
#
# Epoch: 59
# Epoch:59 --Progress(%):24.43-- Loss:0.65 -- Acc:77.27
# Epoch:59 --Progress(%):49.15-- Loss:0.66 -- Acc:76.96
# Epoch:59 --Progress(%):73.86-- Loss:0.65 -- Acc:76.99
# Epoch:59 --Progress(%):98.58-- Loss:0.66 -- Acc:76.75
# Epoch:59 --Val Loss:0.73 -- Acc:73.52
#
# Epoch: 60
# Epoch:60 --Progress(%):24.43-- Loss:0.65 -- Acc:76.70
# Epoch:60 --Progress(%):49.15-- Loss:0.64 -- Acc:77.29
# Epoch:60 --Progress(%):73.86-- Loss:0.65 -- Acc:77.08
# Epoch:60 --Progress(%):98.58-- Loss:0.65 -- Acc:76.92
# Epoch:60 --Val Loss:0.72 -- Acc:74.54
#
# Epoch: 61
# Epoch:61 --Progress(%):24.43-- Loss:0.63 -- Acc:77.68
# Epoch:61 --Progress(%):49.15-- Loss:0.64 -- Acc:77.24
# Epoch:61 --Progress(%):73.86-- Loss:0.64 -- Acc:77.16
# Epoch:61 --Progress(%):98.58-- Loss:0.65 -- Acc:77.01
# Epoch:61 --Val Loss:0.69 -- Acc:75.58
# Saving the best model.
#
# Epoch: 62
# Epoch:62 --Progress(%):24.43-- Loss:0.64 -- Acc:77.63
# Epoch:62 --Progress(%):49.15-- Loss:0.64 -- Acc:77.26
# Epoch:62 --Progress(%):73.86-- Loss:0.64 -- Acc:77.22
# Epoch:62 --Progress(%):98.58-- Loss:0.64 -- Acc:77.33
# Epoch:62 --Val Loss:0.71 -- Acc:74.86
#
# Epoch: 63
# Epoch:63 --Progress(%):24.43-- Loss:0.63 -- Acc:77.34
# Epoch:63 --Progress(%):49.15-- Loss:0.64 -- Acc:77.34
# Epoch:63 --Progress(%):73.86-- Loss:0.64 -- Acc:77.52
# Epoch:63 --Progress(%):98.58-- Loss:0.64 -- Acc:77.48
# Epoch:63 --Val Loss:0.69 -- Acc:75.04
#
# Epoch: 64
# Epoch:64 --Progress(%):24.43-- Loss:0.63 -- Acc:77.61
# Epoch:64 --Progress(%):49.15-- Loss:0.63 -- Acc:77.73
# Epoch:64 --Progress(%):73.86-- Loss:0.63 -- Acc:77.71
# Epoch:64 --Progress(%):98.58-- Loss:0.64 -- Acc:77.62
# Epoch:64 --Val Loss:0.71 -- Acc:75.94
# Saving the best model.
#
# Epoch: 65
# Epoch:65 --Progress(%):24.43-- Loss:0.63 -- Acc:77.29
# Epoch:65 --Progress(%):49.15-- Loss:0.63 -- Acc:77.52
# Epoch:65 --Progress(%):73.86-- Loss:0.63 -- Acc:77.71
# Epoch:65 --Progress(%):98.58-- Loss:0.62 -- Acc:77.91
# Epoch:65 --Val Loss:0.68 -- Acc:75.18
#
# Epoch: 66
# Epoch:66 --Progress(%):24.43-- Loss:0.61 -- Acc:78.46
# Epoch:66 --Progress(%):49.15-- Loss:0.61 -- Acc:78.31
# Epoch:66 --Progress(%):73.86-- Loss:0.62 -- Acc:78.10
# Epoch:66 --Progress(%):98.58-- Loss:0.62 -- Acc:78.04
# Epoch:66 --Val Loss:0.67 -- Acc:75.94
#
# Epoch: 67
# Epoch:67 --Progress(%):24.43-- Loss:0.61 -- Acc:78.11
# Epoch:67 --Progress(%):49.15-- Loss:0.61 -- Acc:78.34
# Epoch:67 --Progress(%):73.86-- Loss:0.61 -- Acc:78.15
# Epoch:67 --Progress(%):98.58-- Loss:0.62 -- Acc:78.10
# Epoch:67 --Val Loss:0.69 -- Acc:75.54
#
# Epoch: 68
# Epoch:68 --Progress(%):24.43-- Loss:0.62 -- Acc:78.03
# Epoch:68 --Progress(%):49.15-- Loss:0.61 -- Acc:78.20
# Epoch:68 --Progress(%):73.86-- Loss:0.61 -- Acc:78.30
# Epoch:68 --Progress(%):98.58-- Loss:0.61 -- Acc:78.30
# Epoch:68 --Val Loss:0.70 -- Acc:75.74
#
# Epoch: 69
# Epoch:69 --Progress(%):24.43-- Loss:0.60 -- Acc:78.84
# Epoch:69 --Progress(%):49.15-- Loss:0.60 -- Acc:78.90
# Epoch:69 --Progress(%):73.86-- Loss:0.61 -- Acc:78.64
# Epoch:69 --Progress(%):98.58-- Loss:0.61 -- Acc:78.57
# Epoch:69 --Val Loss:0.68 -- Acc:76.50
# Saving the best model.
#
# Epoch: 70
# Epoch:70 --Progress(%):24.43-- Loss:0.62 -- Acc:78.19
# Epoch:70 --Progress(%):49.15-- Loss:0.61 -- Acc:78.59
# Epoch:70 --Progress(%):73.86-- Loss:0.61 -- Acc:78.78
# Epoch:70 --Progress(%):98.58-- Loss:0.60 -- Acc:78.88
# Epoch:70 --Val Loss:0.66 -- Acc:76.38
#
# Epoch: 71
# Epoch:71 --Progress(%):24.43-- Loss:0.59 -- Acc:79.37
# Epoch:71 --Progress(%):49.15-- Loss:0.59 -- Acc:79.04
# Epoch:71 --Progress(%):73.86-- Loss:0.59 -- Acc:79.11
# Epoch:71 --Progress(%):98.58-- Loss:0.60 -- Acc:79.08
# Epoch:71 --Val Loss:0.67 -- Acc:76.50
#
# Epoch: 72
# Epoch:72 --Progress(%):24.43-- Loss:0.58 -- Acc:79.88
# Epoch:72 --Progress(%):49.15-- Loss:0.59 -- Acc:79.25
# Epoch:72 --Progress(%):73.86-- Loss:0.60 -- Acc:79.13
# Epoch:72 --Progress(%):98.58-- Loss:0.60 -- Acc:79.01
# Epoch:72 --Val Loss:0.68 -- Acc:77.02
# Saving the best model.
#
# Epoch: 73
# Epoch:73 --Progress(%):24.43-- Loss:0.57 -- Acc:80.02
# Epoch:73 --Progress(%):49.15-- Loss:0.58 -- Acc:79.60
# Epoch:73 --Progress(%):73.86-- Loss:0.59 -- Acc:79.54
# Epoch:73 --Progress(%):98.58-- Loss:0.59 -- Acc:79.43
# Epoch:73 --Val Loss:0.67 -- Acc:76.28
#
# Epoch: 74
# Epoch:74 --Progress(%):24.43-- Loss:0.57 -- Acc:79.97
# Epoch:74 --Progress(%):49.15-- Loss:0.58 -- Acc:79.62
# Epoch:74 --Progress(%):73.86-- Loss:0.58 -- Acc:79.49
# Epoch:74 --Progress(%):98.58-- Loss:0.58 -- Acc:79.48
# Epoch:74 --Val Loss:0.66 -- Acc:76.84
#
# Epoch: 75
# Epoch:75 --Progress(%):24.43-- Loss:0.58 -- Acc:79.71
# Epoch:75 --Progress(%):49.15-- Loss:0.58 -- Acc:79.60
# Epoch:75 --Progress(%):73.86-- Loss:0.58 -- Acc:79.66
# Epoch:75 --Progress(%):98.58-- Loss:0.58 -- Acc:79.57
# Epoch:75 --Val Loss:0.66 -- Acc:76.86
#
# Epoch: 76
# Epoch:76 --Progress(%):24.43-- Loss:0.57 -- Acc:79.80
# Epoch:76 --Progress(%):49.15-- Loss:0.57 -- Acc:79.98
# Epoch:76 --Progress(%):73.86-- Loss:0.57 -- Acc:79.74
# Epoch:76 --Progress(%):98.58-- Loss:0.57 -- Acc:79.81
# Epoch:76 --Val Loss:0.65 -- Acc:77.90
# Saving the best model.
#
# Epoch: 77
# Epoch:77 --Progress(%):24.43-- Loss:0.57 -- Acc:80.00
# Epoch:77 --Progress(%):49.15-- Loss:0.57 -- Acc:80.04
# Epoch:77 --Progress(%):73.86-- Loss:0.57 -- Acc:79.82
# Epoch:77 --Progress(%):98.58-- Loss:0.57 -- Acc:79.84
# Epoch:77 --Val Loss:0.65 -- Acc:77.10
#
# Epoch: 78
# Epoch:78 --Progress(%):24.43-- Loss:0.56 -- Acc:80.24
# Epoch:78 --Progress(%):49.15-- Loss:0.57 -- Acc:80.07
# Epoch:78 --Progress(%):73.86-- Loss:0.57 -- Acc:79.99
# Epoch:78 --Progress(%):98.58-- Loss:0.56 -- Acc:80.13
# Epoch:78 --Val Loss:0.66 -- Acc:77.28
#
# Epoch: 79
# Epoch:79 --Progress(%):24.43-- Loss:0.55 -- Acc:80.57
# Epoch:79 --Progress(%):49.15-- Loss:0.56 -- Acc:80.25
# Epoch:79 --Progress(%):73.86-- Loss:0.56 -- Acc:80.19
# Epoch:79 --Progress(%):98.58-- Loss:0.56 -- Acc:80.14
# Epoch:79 --Val Loss:0.65 -- Acc:77.14
#
# Epoch: 80
# Epoch:80 --Progress(%):24.43-- Loss:0.56 -- Acc:80.27
# Epoch:80 --Progress(%):49.15-- Loss:0.56 -- Acc:80.66
# Epoch:80 --Progress(%):73.86-- Loss:0.56 -- Acc:80.41
# Epoch:80 --Progress(%):98.58-- Loss:0.56 -- Acc:80.30
# Epoch:80 --Val Loss:0.64 -- Acc:77.02
#
# Epoch: 81
# Epoch:81 --Progress(%):24.43-- Loss:0.56 -- Acc:80.19
# Epoch:81 --Progress(%):49.15-- Loss:0.56 -- Acc:80.44
# Epoch:81 --Progress(%):73.86-- Loss:0.55 -- Acc:80.49
# Epoch:81 --Progress(%):98.58-- Loss:0.56 -- Acc:80.42
# Epoch:81 --Val Loss:0.63 -- Acc:78.32
# Saving the best model.
#
# Epoch: 82
# Epoch:82 --Progress(%):24.43-- Loss:0.56 -- Acc:79.92
# Epoch:82 --Progress(%):49.15-- Loss:0.56 -- Acc:80.44
# Epoch:82 --Progress(%):73.86-- Loss:0.56 -- Acc:80.45
# Epoch:82 --Progress(%):98.58-- Loss:0.56 -- Acc:80.52
# Epoch:82 --Val Loss:0.64 -- Acc:78.06
#
# Epoch: 83
# Epoch:83 --Progress(%):24.43-- Loss:0.55 -- Acc:80.68
# Epoch:83 --Progress(%):49.15-- Loss:0.54 -- Acc:80.75
# Epoch:83 --Progress(%):73.86-- Loss:0.55 -- Acc:80.60
# Epoch:83 --Progress(%):98.58-- Loss:0.55 -- Acc:80.77
# Epoch:83 --Val Loss:0.65 -- Acc:77.80
#
# Epoch: 84
# Epoch:84 --Progress(%):24.43-- Loss:0.56 -- Acc:80.40
# Epoch:84 --Progress(%):49.15-- Loss:0.54 -- Acc:80.78
# Epoch:84 --Progress(%):73.86-- Loss:0.54 -- Acc:80.88
# Epoch:84 --Progress(%):98.58-- Loss:0.54 -- Acc:80.90
# Epoch:84 --Val Loss:0.62 -- Acc:78.36
# Saving the best model.
#
# Epoch: 85
# Epoch:85 --Progress(%):24.43-- Loss:0.54 -- Acc:81.31
# Epoch:85 --Progress(%):49.15-- Loss:0.54 -- Acc:80.99
# Epoch:85 --Progress(%):73.86-- Loss:0.54 -- Acc:81.19
# Epoch:85 --Progress(%):98.58-- Loss:0.54 -- Acc:81.01
# Epoch:85 --Val Loss:0.62 -- Acc:78.42
# Saving the best model.
#
# Epoch: 86
# Epoch:86 --Progress(%):24.43-- Loss:0.55 -- Acc:80.73
# Epoch:86 --Progress(%):49.15-- Loss:0.54 -- Acc:80.77
# Epoch:86 --Progress(%):73.86-- Loss:0.53 -- Acc:81.32
# Epoch:86 --Progress(%):98.58-- Loss:0.54 -- Acc:81.29
# Epoch:86 --Val Loss:0.61 -- Acc:78.44
# Saving the best model.
#
# Epoch: 87
# Epoch:87 --Progress(%):24.43-- Loss:0.54 -- Acc:80.83
# Epoch:87 --Progress(%):49.15-- Loss:0.53 -- Acc:81.47
# Epoch:87 --Progress(%):73.86-- Loss:0.53 -- Acc:81.34
# Epoch:87 --Progress(%):98.58-- Loss:0.53 -- Acc:81.31
# Epoch:87 --Val Loss:0.61 -- Acc:78.52
# Saving the best model.
#
# Epoch: 88
# Epoch:88 --Progress(%):24.43-- Loss:0.53 -- Acc:81.11
# Epoch:88 --Progress(%):49.15-- Loss:0.53 -- Acc:81.05
# Epoch:88 --Progress(%):73.86-- Loss:0.53 -- Acc:81.11
# Epoch:88 --Progress(%):98.58-- Loss:0.53 -- Acc:81.11
# Epoch:88 --Val Loss:0.61 -- Acc:79.20
# Saving the best model.
#
# Epoch: 89
# Epoch:89 --Progress(%):24.43-- Loss:0.53 -- Acc:81.51
# Epoch:89 --Progress(%):49.15-- Loss:0.53 -- Acc:81.42
# Epoch:89 --Progress(%):73.86-- Loss:0.52 -- Acc:81.54
# Epoch:89 --Progress(%):98.58-- Loss:0.53 -- Acc:81.51
# Epoch:89 --Val Loss:0.63 -- Acc:78.56
#
# Epoch: 90
# Epoch:90 --Progress(%):24.43-- Loss:0.51 -- Acc:82.40
# Epoch:90 --Progress(%):49.15-- Loss:0.51 -- Acc:82.18
# Epoch:90 --Progress(%):73.86-- Loss:0.52 -- Acc:81.89
# Epoch:90 --Progress(%):98.58-- Loss:0.52 -- Acc:81.90
# Epoch:90 --Val Loss:0.62 -- Acc:78.70
#
# Epoch: 91
# Epoch:91 --Progress(%):24.43-- Loss:0.52 -- Acc:81.82
# Epoch:91 --Progress(%):49.15-- Loss:0.52 -- Acc:81.74
# Epoch:91 --Progress(%):73.86-- Loss:0.52 -- Acc:81.72
# Epoch:91 --Progress(%):98.58-- Loss:0.52 -- Acc:81.56
# Epoch:91 --Val Loss:0.64 -- Acc:78.68
#
# Epoch: 92
# Epoch:92 --Progress(%):24.43-- Loss:0.52 -- Acc:81.56
# Epoch:92 --Progress(%):49.15-- Loss:0.51 -- Acc:82.01
# Epoch:92 --Progress(%):73.86-- Loss:0.51 -- Acc:81.90
# Epoch:92 --Progress(%):98.58-- Loss:0.52 -- Acc:81.82
# Epoch:92 --Val Loss:0.59 -- Acc:79.38
# Saving the best model.
#
# Epoch: 93
# Epoch:93 --Progress(%):24.43-- Loss:0.50 -- Acc:82.22
# Epoch:93 --Progress(%):49.15-- Loss:0.51 -- Acc:82.01
# Epoch:93 --Progress(%):73.86-- Loss:0.51 -- Acc:81.95
# Epoch:93 --Progress(%):98.58-- Loss:0.51 -- Acc:81.88
# Epoch:93 --Val Loss:0.60 -- Acc:79.86
# Saving the best model.
#
# Epoch: 94
# Epoch:94 --Progress(%):24.43-- Loss:0.51 -- Acc:82.00
# Epoch:94 --Progress(%):49.15-- Loss:0.51 -- Acc:82.12
# Epoch:94 --Progress(%):73.86-- Loss:0.51 -- Acc:82.14
# Epoch:94 --Progress(%):98.58-- Loss:0.51 -- Acc:82.22
# Epoch:94 --Val Loss:0.62 -- Acc:78.70
#
# Epoch: 95
# Epoch:95 --Progress(%):24.43-- Loss:0.51 -- Acc:81.97
# Epoch:95 --Progress(%):49.15-- Loss:0.52 -- Acc:81.88
# Epoch:95 --Progress(%):73.86-- Loss:0.51 -- Acc:81.92
# Epoch:95 --Progress(%):98.58-- Loss:0.51 -- Acc:81.99
# Epoch:95 --Val Loss:0.63 -- Acc:79.64
#
# Epoch: 96
# Epoch:96 --Progress(%):24.43-- Loss:0.50 -- Acc:82.54
# Epoch:96 --Progress(%):49.15-- Loss:0.51 -- Acc:82.25
# Epoch:96 --Progress(%):73.86-- Loss:0.51 -- Acc:81.94
# Epoch:96 --Progress(%):98.58-- Loss:0.51 -- Acc:82.16
# Epoch:96 --Val Loss:0.58 -- Acc:79.90
# Saving the best model.
#
# Epoch: 97
# Epoch:97 --Progress(%):24.43-- Loss:0.49 -- Acc:82.40
# Epoch:97 --Progress(%):49.15-- Loss:0.50 -- Acc:82.37
# Epoch:97 --Progress(%):73.86-- Loss:0.51 -- Acc:82.03
# Epoch:97 --Progress(%):98.58-- Loss:0.50 -- Acc:82.27
# Epoch:97 --Val Loss:0.62 -- Acc:78.62
#
# Epoch: 98
# Epoch:98 --Progress(%):24.43-- Loss:0.49 -- Acc:82.81
# Epoch:98 --Progress(%):49.15-- Loss:0.50 -- Acc:82.57
# Epoch:98 --Progress(%):73.86-- Loss:0.49 -- Acc:82.78
# Epoch:98 --Progress(%):98.58-- Loss:0.50 -- Acc:82.74
# Epoch:98 --Val Loss:0.62 -- Acc:78.76
#
# Epoch: 99
# Epoch:99 --Progress(%):24.43-- Loss:0.50 -- Acc:82.50
# Epoch:99 --Progress(%):49.15-- Loss:0.50 -- Acc:82.45
# Epoch:99 --Progress(%):73.86-- Loss:0.50 -- Acc:82.35
# Epoch:99 --Progress(%):98.58-- Loss:0.50 -- Acc:82.48
# Epoch:99 --Val Loss:0.60 -- Acc:79.20
# ***** Begin testing *****
# Epoch:99 --Test Loss:0.61 -- Acc:79.27
