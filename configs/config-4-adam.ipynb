# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# data  sample_data

# %%
# !python --version
# Out:
# Python 3.7.15

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.1.1)

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.1+cu113)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: torch==1.12.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.9.24)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import os
import argparse

# %%
import torch.utils.data as data

# %%
import time
import sys

# %%
import os
import os
import sys
import time
import math

import torch.nn as nn
import torch.nn.init as init
#_, term_width = os.popen('stty size', 'r').read().split()
#term_width = int(term_width)

# %%
def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
#from utils import progress_bar

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time
def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
start_epoch = 0
best_acc = 0

# %%
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
# Out:
# ==> Preparing data..

# %%
trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
# Out:
# Files already downloaded and verified

# %%
trainset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomCrop(size=(32, 32), padding=4)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(trainset) * VALID_RATIO)
n_valid_examples = len(trainset) - n_train_examples

train_data, valid_data = data.random_split(trainset, 
                                           [n_train_examples, n_valid_examples])

# %%
train_data

# %%
valid_data

# %%
trainset=train_data

# %%
valset = valid_data

# %%
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

# %%
valloader = torch.utils.data.DataLoader(
    valset, batch_size=128, shuffle=True, num_workers=2)

# %%
testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
# Out:
# Files already downloaded and verified

# %%
testset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %%
## model to use
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        """
        in_planes: C_in for conv1 and Sequential.Conv2d
        planes: F_i
        """
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=0, bias=False) #this is wehere the shrinking happens
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        #if stride != 1 or in_planes != self.expansion*planes:
        self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=3, stride=stride, padding=0, bias=False), #padding was 1
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks,  num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32
        """
        in_planes: C_out of layer1
        """
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=1)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=1)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
            """
            in_planes becomes the output of the current layer
            """
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 7) # to be understood
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# %%
print('==> Building model..')
net = ResNet18()
net = net.to(device)
# Out:
# ==> Building model..

# %%
## For our model
from torchsummary import summary
summary(net, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  9,216
# |    |    └─BatchNorm2d: 3-2             64
# |    |    └─Conv2d: 3-3                  9,216
# |    |    └─BatchNorm2d: 3-4             64
# |    |    └─Sequential: 3-5              9,280
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  9,216
# |    |    └─BatchNorm2d: 3-7             64
# |    |    └─Conv2d: 3-8                  9,216
# |    |    └─BatchNorm2d: 3-9             64
# |    |    └─Sequential: 3-10             9,280
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 18,432
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             18,560
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 36,864
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Sequential: 3-20             36,992
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 73,728
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             73,984
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 147,456
# |    |    └─BatchNorm2d: 3-27            256
# |    |    └─Conv2d: 3-28                 147,456
# |    |    └─BatchNorm2d: 3-29            256
# |    |    └─Sequential: 3-30             147,712
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 294,912
# |    |    └─BatchNorm2d: 3-32            512
# |    |    └─Conv2d: 3-33                 589,824
# |    |    └─BatchNorm2d: 3-34            512
# |    |    └─Sequential: 3-35             295,424
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 589,824
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             590,336
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 3,935,274
# Trainable params: 3,935,274
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  9,216
# |    |    └─BatchNorm2d: 3-2             64
# |    |    └─Conv2d: 3-3                  9,216
# |    |    └─BatchNorm2d: 3-4             64
# |    |    └─Sequential: 3-5              9,280
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  9,216
# |    |    └─BatchNorm2d: 3-7             64
# |    |    └─Conv2d: 3-8                  9,216
# |    |    └─BatchNorm2d: 3-9             64
# |    |    └─Sequential: 3-10             9,280
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 18,432
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             18,560
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 36,864
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Sequential: 3-20             36,992
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 73,728
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             73,984
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 147,456
# |    |    └─BatchNorm2d: 3-27            256
# |    |    └─Conv2d: 3-28                 147,456
# |    |    └─BatchNorm2d: 3-29            256
# |    |    └─Sequential: 3-30             147,712
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 294,912
# |    |    └─BatchNorm2d: 3-32            512
# |    |    └─Conv2d: 3-33                 589,824
# |    |    └─BatchNorm2d: 3-34            512
# |    |    └─Sequential: 3-35             295,424
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 589,824
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             590,336
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 3,935,274
# Trainable params: 3,935,274
# Non-trainable params: 0
# =================================================================

# %%
# !pip install torch-summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-summary in /usr/local/lib/python3.7/dist-packages (1.4.5)

# %%
#original model only for reference
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)  # same as the last layer's HxW
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
originalNet = ResNet18()
summary(originalNet, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 294,912
# |    |    └─BatchNorm2d: 3-22            512
# |    |    └─Conv2d: 3-23                 589,824
# |    |    └─BatchNorm2d: 3-24            512
# |    |    └─Sequential: 3-25             33,280
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 589,824
# |    |    └─BatchNorm2d: 3-27            512
# |    |    └─Conv2d: 3-28                 589,824
# |    |    └─BatchNorm2d: 3-29            512
# |    |    └─Sequential: 3-30             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 1,179,648
# |    |    └─BatchNorm2d: 3-32            1,024
# |    |    └─Conv2d: 3-33                 2,359,296
# |    |    └─BatchNorm2d: 3-34            1,024
# |    |    └─Sequential: 3-35             132,096
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 2,359,296
# |    |    └─BatchNorm2d: 3-37            1,024
# |    |    └─Conv2d: 3-38                 2,359,296
# |    |    └─BatchNorm2d: 3-39            1,024
# |    |    └─Sequential: 3-40             --
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 294,912
# |    |    └─BatchNorm2d: 3-22            512
# |    |    └─Conv2d: 3-23                 589,824
# |    |    └─BatchNorm2d: 3-24            512
# |    |    └─Sequential: 3-25             33,280
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 589,824
# |    |    └─BatchNorm2d: 3-27            512
# |    |    └─Conv2d: 3-28                 589,824
# |    |    └─BatchNorm2d: 3-29            512
# |    |    └─Sequential: 3-30             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 1,179,648
# |    |    └─BatchNorm2d: 3-32            1,024
# |    |    └─Conv2d: 3-33                 2,359,296
# |    |    └─BatchNorm2d: 3-34            1,024
# |    |    └─Sequential: 3-35             132,096
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 2,359,296
# |    |    └─BatchNorm2d: 3-37            1,024
# |    |    └─Conv2d: 3-38                 2,359,296
# |    |    └─BatchNorm2d: 3-39            1,024
# |    |    └─Sequential: 3-40             --
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# =================================================================

# %%
## For our model
from torchsummary import summary
summary(net, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  9,216
# |    |    └─BatchNorm2d: 3-2             64
# |    |    └─Conv2d: 3-3                  9,216
# |    |    └─BatchNorm2d: 3-4             64
# |    |    └─Sequential: 3-5              9,280
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  9,216
# |    |    └─BatchNorm2d: 3-7             64
# |    |    └─Conv2d: 3-8                  9,216
# |    |    └─BatchNorm2d: 3-9             64
# |    |    └─Sequential: 3-10             9,280
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 18,432
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             18,560
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 36,864
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Sequential: 3-20             36,992
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 73,728
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             73,984
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 147,456
# |    |    └─BatchNorm2d: 3-27            256
# |    |    └─Conv2d: 3-28                 147,456
# |    |    └─BatchNorm2d: 3-29            256
# |    |    └─Sequential: 3-30             147,712
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 294,912
# |    |    └─BatchNorm2d: 3-32            512
# |    |    └─Conv2d: 3-33                 589,824
# |    |    └─BatchNorm2d: 3-34            512
# |    |    └─Sequential: 3-35             295,424
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 589,824
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             590,336
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 3,935,274
# Trainable params: 3,935,274
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            864
# ├─BatchNorm2d: 1-2                       64
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  9,216
# |    |    └─BatchNorm2d: 3-2             64
# |    |    └─Conv2d: 3-3                  9,216
# |    |    └─BatchNorm2d: 3-4             64
# |    |    └─Sequential: 3-5              9,280
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  9,216
# |    |    └─BatchNorm2d: 3-7             64
# |    |    └─Conv2d: 3-8                  9,216
# |    |    └─BatchNorm2d: 3-9             64
# |    |    └─Sequential: 3-10             9,280
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 18,432
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             18,560
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 36,864
# |    |    └─BatchNorm2d: 3-17            128
# |    |    └─Conv2d: 3-18                 36,864
# |    |    └─BatchNorm2d: 3-19            128
# |    |    └─Sequential: 3-20             36,992
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 73,728
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             73,984
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 147,456
# |    |    └─BatchNorm2d: 3-27            256
# |    |    └─Conv2d: 3-28                 147,456
# |    |    └─BatchNorm2d: 3-29            256
# |    |    └─Sequential: 3-30             147,712
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 294,912
# |    |    └─BatchNorm2d: 3-32            512
# |    |    └─Conv2d: 3-33                 589,824
# |    |    └─BatchNorm2d: 3-34            512
# |    |    └─Sequential: 3-35             295,424
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 589,824
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             590,336
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 3,935,274
# Trainable params: 3,935,274
# Non-trainable params: 0
# =================================================================

# %%
device
# Out:
# 'cuda'

# %%
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# %%
resume = False
if resume == True:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
    checkpoint = torch.load('./checkpoint/ckpt.pth')
    net.load_state_dict(checkpoint['net'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch']

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0005,
                      weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.1)

# %%
from tqdm import tqdm

# %%
len(trainloader)
# Out:
# 352

# %%
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    steps = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        steps = steps+1
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        #progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
        #             % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
        if steps%87==0:
            print(f"Epoch:{epoch} --Progress(%):{batch_idx/len(trainloader)*100.:.2f}-- Loss:{train_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")

# %%
def val(epoch):
    global best_acc
    net.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            #progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            #             % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print(f"Epoch:{epoch} --Val Loss:{val_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")
            
    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving the best model.')
        #state = {
        #    'net': net.state_dict(),
        #    'acc': acc,
        #    'epoch': epoch,
        #}
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        #torch.save(state, './checkpoint/ckpt.pth')
        
        torch.save(net.state_dict(), './checkpoint/ckpt.pth')
        best_acc = acc

# %%
def test(epoch):
    print("***** Begin testing *****")
    net.load_state_dict(torch.load('./checkpoint/ckpt.pth'))
    net.eval()
    
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            #progress_bar(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            #             % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))
    print(f"Epoch:{epoch} --Test Loss:{test_loss/(batch_idx+1):.2f} -- Acc:{100.*correct/total:.2f}")

# %%
for epoch in range(start_epoch, start_epoch+100):
    train(epoch)
    scheduler.step()
    val(epoch)
    
test(epoch)
# Out:
# Epoch: 0
# Epoch:0 --Progress(%):24.43-- Loss:1.80 -- Acc:31.82
# Epoch:0 --Progress(%):49.15-- Loss:1.66 -- Acc:37.86
# Epoch:0 --Progress(%):73.86-- Loss:1.57 -- Acc:41.91
# Epoch:0 --Progress(%):98.58-- Loss:1.49 -- Acc:44.94
# Epoch:0 --Val Loss:1.34 -- Acc:52.96
# Saving the best model.
#
# Epoch: 1
# Epoch:1 --Progress(%):24.43-- Loss:1.16 -- Acc:58.53
# Epoch:1 --Progress(%):49.15-- Loss:1.15 -- Acc:58.83
# Epoch:1 --Progress(%):73.86-- Loss:1.14 -- Acc:59.45
# Epoch:1 --Progress(%):98.58-- Loss:1.11 -- Acc:60.08
# Epoch:1 --Val Loss:1.27 -- Acc:54.38
# Saving the best model.
#
# Epoch: 2
# Epoch:2 --Progress(%):24.43-- Loss:1.00 -- Acc:63.87
# Epoch:2 --Progress(%):49.15-- Loss:1.00 -- Acc:64.04
# Epoch:2 --Progress(%):73.86-- Loss:0.97 -- Acc:65.11
# Epoch:2 --Progress(%):98.58-- Loss:0.96 -- Acc:65.60
# Epoch:2 --Val Loss:1.15 -- Acc:59.68
# Saving the best model.
#
# Epoch: 3
# Epoch:3 --Progress(%):24.43-- Loss:0.88 -- Acc:68.80
# Epoch:3 --Progress(%):49.15-- Loss:0.88 -- Acc:68.98
# Epoch:3 --Progress(%):73.86-- Loss:0.86 -- Acc:69.50
# Epoch:3 --Progress(%):98.58-- Loss:0.85 -- Acc:70.02
# Epoch:3 --Val Loss:0.94 -- Acc:67.42
# Saving the best model.
#
# Epoch: 4
# Epoch:4 --Progress(%):24.43-- Loss:0.78 -- Acc:72.25
# Epoch:4 --Progress(%):49.15-- Loss:0.77 -- Acc:72.80
# Epoch:4 --Progress(%):73.86-- Loss:0.77 -- Acc:72.92
# Epoch:4 --Progress(%):98.58-- Loss:0.77 -- Acc:73.08
# Epoch:4 --Val Loss:0.86 -- Acc:70.74
# Saving the best model.
#
# Epoch: 5
# Epoch:5 --Progress(%):24.43-- Loss:0.71 -- Acc:75.57
# Epoch:5 --Progress(%):49.15-- Loss:0.71 -- Acc:75.30
# Epoch:5 --Progress(%):73.86-- Loss:0.71 -- Acc:75.46
# Epoch:5 --Progress(%):98.58-- Loss:0.71 -- Acc:75.56
# Epoch:5 --Val Loss:0.85 -- Acc:70.72
#
# Epoch: 6
# Epoch:6 --Progress(%):24.43-- Loss:0.67 -- Acc:76.47
# Epoch:6 --Progress(%):49.15-- Loss:0.67 -- Acc:76.88
# Epoch:6 --Progress(%):73.86-- Loss:0.67 -- Acc:76.82
# Epoch:6 --Progress(%):98.58-- Loss:0.67 -- Acc:76.88
# Epoch:6 --Val Loss:0.85 -- Acc:71.22
# Saving the best model.
#
# Epoch: 7
# Epoch:7 --Progress(%):24.43-- Loss:0.62 -- Acc:78.56
# Epoch:7 --Progress(%):49.15-- Loss:0.63 -- Acc:78.25
# Epoch:7 --Progress(%):73.86-- Loss:0.63 -- Acc:78.46
# Epoch:7 --Progress(%):98.58-- Loss:0.63 -- Acc:78.37
# Epoch:7 --Val Loss:0.78 -- Acc:73.58
# Saving the best model.
#
# Epoch: 8
# Epoch:8 --Progress(%):24.43-- Loss:0.61 -- Acc:79.34
# Epoch:8 --Progress(%):49.15-- Loss:0.60 -- Acc:79.48
# Epoch:8 --Progress(%):73.86-- Loss:0.59 -- Acc:79.59
# Epoch:8 --Progress(%):98.58-- Loss:0.59 -- Acc:79.51
# Epoch:8 --Val Loss:0.74 -- Acc:75.06
# Saving the best model.
#
# Epoch: 9
# Epoch:9 --Progress(%):24.43-- Loss:0.54 -- Acc:81.52
# Epoch:9 --Progress(%):49.15-- Loss:0.55 -- Acc:80.96
# Epoch:9 --Progress(%):73.86-- Loss:0.56 -- Acc:80.62
# Epoch:9 --Progress(%):98.58-- Loss:0.56 -- Acc:80.56
# Epoch:9 --Val Loss:0.81 -- Acc:73.56
#
# Epoch: 10
# Epoch:10 --Progress(%):24.43-- Loss:0.54 -- Acc:81.30
# Epoch:10 --Progress(%):49.15-- Loss:0.53 -- Acc:81.52
# Epoch:10 --Progress(%):73.86-- Loss:0.54 -- Acc:81.35
# Epoch:10 --Progress(%):98.58-- Loss:0.54 -- Acc:81.33
# Epoch:10 --Val Loss:0.59 -- Acc:79.38
# Saving the best model.
#
# Epoch: 11
# Epoch:11 --Progress(%):24.43-- Loss:0.52 -- Acc:82.47
# Epoch:11 --Progress(%):49.15-- Loss:0.52 -- Acc:82.40
# Epoch:11 --Progress(%):73.86-- Loss:0.52 -- Acc:82.35
# Epoch:11 --Progress(%):98.58-- Loss:0.52 -- Acc:82.20
# Epoch:11 --Val Loss:0.62 -- Acc:78.66
#
# Epoch: 12
# Epoch:12 --Progress(%):24.43-- Loss:0.49 -- Acc:83.34
# Epoch:12 --Progress(%):49.15-- Loss:0.49 -- Acc:83.16
# Epoch:12 --Progress(%):73.86-- Loss:0.50 -- Acc:82.98
# Epoch:12 --Progress(%):98.58-- Loss:0.49 -- Acc:83.01
# Epoch:12 --Val Loss:0.64 -- Acc:77.82
#
# Epoch: 13
# Epoch:13 --Progress(%):24.43-- Loss:0.46 -- Acc:84.47
# Epoch:13 --Progress(%):49.15-- Loss:0.48 -- Acc:83.72
# Epoch:13 --Progress(%):73.86-- Loss:0.48 -- Acc:83.69
# Epoch:13 --Progress(%):98.58-- Loss:0.48 -- Acc:83.68
# Epoch:13 --Val Loss:0.63 -- Acc:78.32
#
# Epoch: 14
# Epoch:14 --Progress(%):24.43-- Loss:0.44 -- Acc:84.77
# Epoch:14 --Progress(%):49.15-- Loss:0.46 -- Acc:84.16
# Epoch:14 --Progress(%):73.86-- Loss:0.46 -- Acc:84.03
# Epoch:14 --Progress(%):98.58-- Loss:0.46 -- Acc:84.08
# Epoch:14 --Val Loss:0.59 -- Acc:80.02
# Saving the best model.
#
# Epoch: 15
# Epoch:15 --Progress(%):24.43-- Loss:0.44 -- Acc:84.64
# Epoch:15 --Progress(%):49.15-- Loss:0.44 -- Acc:84.82
# Epoch:15 --Progress(%):73.86-- Loss:0.44 -- Acc:84.67
# Epoch:15 --Progress(%):98.58-- Loss:0.45 -- Acc:84.66
# Epoch:15 --Val Loss:0.61 -- Acc:79.10
#
# Epoch: 16
# Epoch:16 --Progress(%):24.43-- Loss:0.43 -- Acc:85.08
# Epoch:16 --Progress(%):49.15-- Loss:0.43 -- Acc:84.91
# Epoch:16 --Progress(%):73.86-- Loss:0.44 -- Acc:84.94
# Epoch:16 --Progress(%):98.58-- Loss:0.43 -- Acc:84.99
# Epoch:16 --Val Loss:0.53 -- Acc:81.40
# Saving the best model.
#
# Epoch: 17
# Epoch:17 --Progress(%):24.43-- Loss:0.40 -- Acc:85.89
# Epoch:17 --Progress(%):49.15-- Loss:0.41 -- Acc:86.12
# Epoch:17 --Progress(%):73.86-- Loss:0.41 -- Acc:85.84
# Epoch:17 --Progress(%):98.58-- Loss:0.42 -- Acc:85.76
# Epoch:17 --Val Loss:0.72 -- Acc:76.32
#
# Epoch: 18
# Epoch:18 --Progress(%):24.43-- Loss:0.38 -- Acc:86.78
# Epoch:18 --Progress(%):49.15-- Loss:0.39 -- Acc:86.72
# Epoch:18 --Progress(%):73.86-- Loss:0.39 -- Acc:86.54
# Epoch:18 --Progress(%):98.58-- Loss:0.40 -- Acc:86.34
# Epoch:18 --Val Loss:0.69 -- Acc:78.52
#
# Epoch: 19
# Epoch:19 --Progress(%):24.43-- Loss:0.37 -- Acc:87.27
# Epoch:19 --Progress(%):49.15-- Loss:0.38 -- Acc:87.13
# Epoch:19 --Progress(%):73.86-- Loss:0.38 -- Acc:86.87
# Epoch:19 --Progress(%):98.58-- Loss:0.39 -- Acc:86.79
# Epoch:19 --Val Loss:0.54 -- Acc:81.72
# Saving the best model.
#
# Epoch: 20
# Epoch:20 --Progress(%):24.43-- Loss:0.36 -- Acc:87.56
# Epoch:20 --Progress(%):49.15-- Loss:0.36 -- Acc:87.56
# Epoch:20 --Progress(%):73.86-- Loss:0.37 -- Acc:87.12
# Epoch:20 --Progress(%):98.58-- Loss:0.38 -- Acc:87.00
# Epoch:20 --Val Loss:0.53 -- Acc:82.52
# Saving the best model.
#
# Epoch: 21
# Epoch:21 --Progress(%):24.43-- Loss:0.34 -- Acc:88.57
# Epoch:21 --Progress(%):49.15-- Loss:0.35 -- Acc:88.05
# Epoch:21 --Progress(%):73.86-- Loss:0.36 -- Acc:87.74
# Epoch:21 --Progress(%):98.58-- Loss:0.37 -- Acc:87.52
# Epoch:21 --Val Loss:0.52 -- Acc:82.32
#
# Epoch: 22
# Epoch:22 --Progress(%):24.43-- Loss:0.34 -- Acc:88.47
# Epoch:22 --Progress(%):49.15-- Loss:0.35 -- Acc:88.17
# Epoch:22 --Progress(%):73.86-- Loss:0.35 -- Acc:88.06
# Epoch:22 --Progress(%):98.58-- Loss:0.36 -- Acc:87.82
# Epoch:22 --Val Loss:0.55 -- Acc:82.06
#
# Epoch: 23
# Epoch:23 --Progress(%):24.43-- Loss:0.33 -- Acc:88.65
# Epoch:23 --Progress(%):49.15-- Loss:0.34 -- Acc:88.56
# Epoch:23 --Progress(%):73.86-- Loss:0.34 -- Acc:88.31
# Epoch:23 --Progress(%):98.58-- Loss:0.35 -- Acc:88.10
# Epoch:23 --Val Loss:0.64 -- Acc:79.32
#
# Epoch: 24
# Epoch:24 --Progress(%):24.43-- Loss:0.32 -- Acc:89.00
# Epoch:24 --Progress(%):49.15-- Loss:0.33 -- Acc:88.74
# Epoch:24 --Progress(%):73.86-- Loss:0.33 -- Acc:88.54
# Epoch:24 --Progress(%):98.58-- Loss:0.33 -- Acc:88.50
# Epoch:24 --Val Loss:0.47 -- Acc:83.76
# Saving the best model.
#
# Epoch: 25
# Epoch:25 --Progress(%):24.43-- Loss:0.31 -- Acc:89.50
# Epoch:25 --Progress(%):49.15-- Loss:0.32 -- Acc:88.92
# Epoch:25 --Progress(%):73.86-- Loss:0.33 -- Acc:88.69
# Epoch:25 --Progress(%):98.58-- Loss:0.33 -- Acc:88.62
# Epoch:25 --Val Loss:0.53 -- Acc:82.52
#
# Epoch: 26
# Epoch:26 --Progress(%):24.43-- Loss:0.31 -- Acc:89.41
# Epoch:26 --Progress(%):49.15-- Loss:0.31 -- Acc:89.15
# Epoch:26 --Progress(%):73.86-- Loss:0.31 -- Acc:89.10
# Epoch:26 --Progress(%):98.58-- Loss:0.32 -- Acc:88.83
# Epoch:26 --Val Loss:0.57 -- Acc:82.10
#
# Epoch: 27
# Epoch:27 --Progress(%):24.43-- Loss:0.31 -- Acc:89.42
# Epoch:27 --Progress(%):49.15-- Loss:0.31 -- Acc:89.36
# Epoch:27 --Progress(%):73.86-- Loss:0.31 -- Acc:89.19
# Epoch:27 --Progress(%):98.58-- Loss:0.31 -- Acc:89.33
# Epoch:27 --Val Loss:0.52 -- Acc:83.54
#
# Epoch: 28
# Epoch:28 --Progress(%):24.43-- Loss:0.30 -- Acc:90.18
# Epoch:28 --Progress(%):49.15-- Loss:0.29 -- Acc:90.45
# Epoch:28 --Progress(%):73.86-- Loss:0.30 -- Acc:89.88
# Epoch:28 --Progress(%):98.58-- Loss:0.31 -- Acc:89.66
# Epoch:28 --Val Loss:0.52 -- Acc:82.64
#
# Epoch: 29
# Epoch:29 --Progress(%):24.43-- Loss:0.29 -- Acc:90.37
# Epoch:29 --Progress(%):49.15-- Loss:0.29 -- Acc:90.17
# Epoch:29 --Progress(%):73.86-- Loss:0.29 -- Acc:89.92
# Epoch:29 --Progress(%):98.58-- Loss:0.29 -- Acc:89.96
# Epoch:29 --Val Loss:0.54 -- Acc:82.02
#
# Epoch: 30
# Epoch:30 --Progress(%):24.43-- Loss:0.28 -- Acc:90.59
# Epoch:30 --Progress(%):49.15-- Loss:0.29 -- Acc:90.38
# Epoch:30 --Progress(%):73.86-- Loss:0.29 -- Acc:90.16
# Epoch:30 --Progress(%):98.58-- Loss:0.29 -- Acc:90.10
# Epoch:30 --Val Loss:0.45 -- Acc:84.98
# Saving the best model.
#
# Epoch: 31
# Epoch:31 --Progress(%):24.43-- Loss:0.27 -- Acc:90.62
# Epoch:31 --Progress(%):49.15-- Loss:0.27 -- Acc:90.74
# Epoch:31 --Progress(%):73.86-- Loss:0.27 -- Acc:90.57
# Epoch:31 --Progress(%):98.58-- Loss:0.28 -- Acc:90.41
# Epoch:31 --Val Loss:0.56 -- Acc:82.44
#
# Epoch: 32
# Epoch:32 --Progress(%):24.43-- Loss:0.28 -- Acc:90.37
# Epoch:32 --Progress(%):49.15-- Loss:0.28 -- Acc:90.32
# Epoch:32 --Progress(%):73.86-- Loss:0.28 -- Acc:90.39
# Epoch:32 --Progress(%):98.58-- Loss:0.28 -- Acc:90.32
# Epoch:32 --Val Loss:0.52 -- Acc:82.92
#
# Epoch: 33
# Epoch:33 --Progress(%):24.43-- Loss:0.25 -- Acc:91.44
# Epoch:33 --Progress(%):49.15-- Loss:0.26 -- Acc:91.17
# Epoch:33 --Progress(%):73.86-- Loss:0.26 -- Acc:91.02
# Epoch:33 --Progress(%):98.58-- Loss:0.27 -- Acc:90.80
# Epoch:33 --Val Loss:0.49 -- Acc:83.76
#
# Epoch: 34
# Epoch:34 --Progress(%):24.43-- Loss:0.25 -- Acc:91.32
# Epoch:34 --Progress(%):49.15-- Loss:0.26 -- Acc:91.21
# Epoch:34 --Progress(%):73.86-- Loss:0.26 -- Acc:90.94
# Epoch:34 --Progress(%):98.58-- Loss:0.27 -- Acc:90.87
# Epoch:34 --Val Loss:0.52 -- Acc:82.46
#
# Epoch: 35
# Epoch:35 --Progress(%):24.43-- Loss:0.25 -- Acc:91.24
# Epoch:35 --Progress(%):49.15-- Loss:0.25 -- Acc:91.26
# Epoch:35 --Progress(%):73.86-- Loss:0.26 -- Acc:91.14
# Epoch:35 --Progress(%):98.58-- Loss:0.26 -- Acc:91.07
# Epoch:35 --Val Loss:0.50 -- Acc:83.26
#
# Epoch: 36
# Epoch:36 --Progress(%):24.43-- Loss:0.24 -- Acc:91.95
# Epoch:36 --Progress(%):49.15-- Loss:0.24 -- Acc:91.70
# Epoch:36 --Progress(%):73.86-- Loss:0.25 -- Acc:91.29
# Epoch:36 --Progress(%):98.58-- Loss:0.26 -- Acc:91.21
# Epoch:36 --Val Loss:0.48 -- Acc:84.36
#
# Epoch: 37
# Epoch:37 --Progress(%):24.43-- Loss:0.24 -- Acc:91.84
# Epoch:37 --Progress(%):49.15-- Loss:0.25 -- Acc:91.52
# Epoch:37 --Progress(%):73.86-- Loss:0.25 -- Acc:91.31
# Epoch:37 --Progress(%):98.58-- Loss:0.25 -- Acc:91.31
# Epoch:37 --Val Loss:0.49 -- Acc:83.92
#
# Epoch: 38
# Epoch:38 --Progress(%):24.43-- Loss:0.24 -- Acc:91.86
# Epoch:38 --Progress(%):49.15-- Loss:0.23 -- Acc:91.79
# Epoch:38 --Progress(%):73.86-- Loss:0.24 -- Acc:91.73
# Epoch:38 --Progress(%):98.58-- Loss:0.24 -- Acc:91.68
# Epoch:38 --Val Loss:0.60 -- Acc:82.08
#
# Epoch: 39
# Epoch:39 --Progress(%):24.43-- Loss:0.22 -- Acc:92.30
# Epoch:39 --Progress(%):49.15-- Loss:0.23 -- Acc:92.09
# Epoch:39 --Progress(%):73.86-- Loss:0.23 -- Acc:92.14
# Epoch:39 --Progress(%):98.58-- Loss:0.24 -- Acc:91.93
# Epoch:39 --Val Loss:0.46 -- Acc:84.40
#
# Epoch: 40
# Epoch:40 --Progress(%):24.43-- Loss:0.22 -- Acc:92.39
# Epoch:40 --Progress(%):49.15-- Loss:0.23 -- Acc:92.25
# Epoch:40 --Progress(%):73.86-- Loss:0.24 -- Acc:91.84
# Epoch:40 --Progress(%):98.58-- Loss:0.24 -- Acc:91.78
# Epoch:40 --Val Loss:0.48 -- Acc:84.80
#
# Epoch: 41
# Epoch:41 --Progress(%):24.43-- Loss:0.21 -- Acc:92.64
# Epoch:41 --Progress(%):49.15-- Loss:0.23 -- Acc:92.34
# Epoch:41 --Progress(%):73.86-- Loss:0.23 -- Acc:92.20
# Epoch:41 --Progress(%):98.58-- Loss:0.23 -- Acc:91.99
# Epoch:41 --Val Loss:0.50 -- Acc:84.26
#
# Epoch: 42
# Epoch:42 --Progress(%):24.43-- Loss:0.20 -- Acc:93.04
# Epoch:42 --Progress(%):49.15-- Loss:0.21 -- Acc:92.80
# Epoch:42 --Progress(%):73.86-- Loss:0.22 -- Acc:92.47
# Epoch:42 --Progress(%):98.58-- Loss:0.22 -- Acc:92.42
# Epoch:42 --Val Loss:0.51 -- Acc:84.10
#
# Epoch: 43
# Epoch:43 --Progress(%):24.43-- Loss:0.21 -- Acc:92.96
# Epoch:43 --Progress(%):49.15-- Loss:0.21 -- Acc:92.85
# Epoch:43 --Progress(%):73.86-- Loss:0.22 -- Acc:92.72
# Epoch:43 --Progress(%):98.58-- Loss:0.22 -- Acc:92.48
# Epoch:43 --Val Loss:0.52 -- Acc:83.42
#
# Epoch: 44
# Epoch:44 --Progress(%):24.43-- Loss:0.21 -- Acc:92.71
# Epoch:44 --Progress(%):49.15-- Loss:0.21 -- Acc:92.52
# Epoch:44 --Progress(%):73.86-- Loss:0.22 -- Acc:92.41
# Epoch:44 --Progress(%):98.58-- Loss:0.22 -- Acc:92.36
# Epoch:44 --Val Loss:0.46 -- Acc:85.70
# Saving the best model.
#
# Epoch: 45
# Epoch:45 --Progress(%):24.43-- Loss:0.19 -- Acc:93.76
# Epoch:45 --Progress(%):49.15-- Loss:0.20 -- Acc:93.24
# Epoch:45 --Progress(%):73.86-- Loss:0.21 -- Acc:92.86
# Epoch:45 --Progress(%):98.58-- Loss:0.21 -- Acc:92.65
# Epoch:45 --Val Loss:0.55 -- Acc:82.84
#
# Epoch: 46
# Epoch:46 --Progress(%):24.43-- Loss:0.19 -- Acc:93.58
# Epoch:46 --Progress(%):49.15-- Loss:0.19 -- Acc:93.36
# Epoch:46 --Progress(%):73.86-- Loss:0.20 -- Acc:93.12
# Epoch:46 --Progress(%):98.58-- Loss:0.21 -- Acc:92.92
# Epoch:46 --Val Loss:0.49 -- Acc:84.24
#
# Epoch: 47
# Epoch:47 --Progress(%):24.43-- Loss:0.20 -- Acc:93.34
# Epoch:47 --Progress(%):49.15-- Loss:0.20 -- Acc:93.05
# Epoch:47 --Progress(%):73.86-- Loss:0.21 -- Acc:92.91
# Epoch:47 --Progress(%):98.58-- Loss:0.21 -- Acc:92.73
# Epoch:47 --Val Loss:0.57 -- Acc:82.32
#
# Epoch: 48
# Epoch:48 --Progress(%):24.43-- Loss:0.19 -- Acc:93.27
# Epoch:48 --Progress(%):49.15-- Loss:0.19 -- Acc:93.37
# Epoch:48 --Progress(%):73.86-- Loss:0.20 -- Acc:93.06
# Epoch:48 --Progress(%):98.58-- Loss:0.20 -- Acc:92.95
# Epoch:48 --Val Loss:0.52 -- Acc:85.18
#
# Epoch: 49
# Epoch:49 --Progress(%):24.43-- Loss:0.18 -- Acc:93.90
# Epoch:49 --Progress(%):49.15-- Loss:0.18 -- Acc:93.89
# Epoch:49 --Progress(%):73.86-- Loss:0.18 -- Acc:93.69
# Epoch:49 --Progress(%):98.58-- Loss:0.19 -- Acc:93.34
# Epoch:49 --Val Loss:0.50 -- Acc:83.86
#
# Epoch: 50
# Epoch:50 --Progress(%):24.43-- Loss:0.19 -- Acc:93.55
# Epoch:50 --Progress(%):49.15-- Loss:0.19 -- Acc:93.36
# Epoch:50 --Progress(%):73.86-- Loss:0.19 -- Acc:93.30
# Epoch:50 --Progress(%):98.58-- Loss:0.20 -- Acc:93.22
# Epoch:50 --Val Loss:0.50 -- Acc:84.48
#
# Epoch: 51
# Epoch:51 --Progress(%):24.43-- Loss:0.17 -- Acc:94.13
# Epoch:51 --Progress(%):49.15-- Loss:0.18 -- Acc:93.85
# Epoch:51 --Progress(%):73.86-- Loss:0.19 -- Acc:93.71
# Epoch:51 --Progress(%):98.58-- Loss:0.19 -- Acc:93.55
# Epoch:51 --Val Loss:0.44 -- Acc:85.64
#
# Epoch: 52
# Epoch:52 --Progress(%):24.43-- Loss:0.17 -- Acc:94.07
# Epoch:52 --Progress(%):49.15-- Loss:0.18 -- Acc:93.87
# Epoch:52 --Progress(%):73.86-- Loss:0.18 -- Acc:93.80
# Epoch:52 --Progress(%):98.58-- Loss:0.19 -- Acc:93.58
# Epoch:52 --Val Loss:0.55 -- Acc:83.68
#
# Epoch: 53
# Epoch:53 --Progress(%):24.43-- Loss:0.19 -- Acc:93.86
# Epoch:53 --Progress(%):49.15-- Loss:0.18 -- Acc:93.88
# Epoch:53 --Progress(%):73.86-- Loss:0.18 -- Acc:93.72
# Epoch:53 --Progress(%):98.58-- Loss:0.19 -- Acc:93.59
# Epoch:53 --Val Loss:0.54 -- Acc:84.46
#
# Epoch: 54
# Epoch:54 --Progress(%):24.43-- Loss:0.18 -- Acc:93.95
# Epoch:54 --Progress(%):49.15-- Loss:0.18 -- Acc:93.76
# Epoch:54 --Progress(%):73.86-- Loss:0.18 -- Acc:93.79
# Epoch:54 --Progress(%):98.58-- Loss:0.18 -- Acc:93.75
# Epoch:54 --Val Loss:0.47 -- Acc:85.48
#
# Epoch: 55
# Epoch:55 --Progress(%):24.43-- Loss:0.16 -- Acc:94.31
# Epoch:55 --Progress(%):49.15-- Loss:0.17 -- Acc:94.17
# Epoch:55 --Progress(%):73.86-- Loss:0.17 -- Acc:94.03
# Epoch:55 --Progress(%):98.58-- Loss:0.18 -- Acc:93.86
# Epoch:55 --Val Loss:0.83 -- Acc:78.36
#
# Epoch: 56
# Epoch:56 --Progress(%):24.43-- Loss:0.16 -- Acc:94.51
# Epoch:56 --Progress(%):49.15-- Loss:0.17 -- Acc:94.35
# Epoch:56 --Progress(%):73.86-- Loss:0.17 -- Acc:94.22
# Epoch:56 --Progress(%):98.58-- Loss:0.17 -- Acc:94.01
# Epoch:56 --Val Loss:0.46 -- Acc:85.12
#
# Epoch: 57
# Epoch:57 --Progress(%):24.43-- Loss:0.16 -- Acc:94.49
# Epoch:57 --Progress(%):49.15-- Loss:0.17 -- Acc:94.20
# Epoch:57 --Progress(%):73.86-- Loss:0.18 -- Acc:94.01
# Epoch:57 --Progress(%):98.58-- Loss:0.18 -- Acc:93.92
# Epoch:57 --Val Loss:0.48 -- Acc:85.26
#
# Epoch: 58
# Epoch:58 --Progress(%):24.43-- Loss:0.15 -- Acc:95.05
# Epoch:58 --Progress(%):49.15-- Loss:0.16 -- Acc:94.60
# Epoch:58 --Progress(%):73.86-- Loss:0.17 -- Acc:94.26
# Epoch:58 --Progress(%):98.58-- Loss:0.17 -- Acc:94.21
# Epoch:58 --Val Loss:0.54 -- Acc:84.08
#
# Epoch: 59
# Epoch:59 --Progress(%):24.43-- Loss:0.16 -- Acc:94.50
# Epoch:59 --Progress(%):49.15-- Loss:0.16 -- Acc:94.66
# Epoch:59 --Progress(%):73.86-- Loss:0.16 -- Acc:94.46
# Epoch:59 --Progress(%):98.58-- Loss:0.16 -- Acc:94.42
# Epoch:59 --Val Loss:0.52 -- Acc:84.64
#
# Epoch: 60
# Epoch:60 --Progress(%):24.43-- Loss:0.15 -- Acc:95.03
# Epoch:60 --Progress(%):49.15-- Loss:0.15 -- Acc:94.80
# Epoch:60 --Progress(%):73.86-- Loss:0.16 -- Acc:94.58
# Epoch:60 --Progress(%):98.58-- Loss:0.16 -- Acc:94.51
# Epoch:60 --Val Loss:0.55 -- Acc:84.08
#
# Epoch: 61
# Epoch:61 --Progress(%):24.43-- Loss:0.15 -- Acc:94.77
# Epoch:61 --Progress(%):49.15-- Loss:0.15 -- Acc:94.81
# Epoch:61 --Progress(%):73.86-- Loss:0.16 -- Acc:94.60
# Epoch:61 --Progress(%):98.58-- Loss:0.16 -- Acc:94.38
# Epoch:61 --Val Loss:0.54 -- Acc:84.86
#
# Epoch: 62
# Epoch:62 --Progress(%):24.43-- Loss:0.14 -- Acc:95.20
# Epoch:62 --Progress(%):49.15-- Loss:0.14 -- Acc:95.04
# Epoch:62 --Progress(%):73.86-- Loss:0.15 -- Acc:94.68
# Epoch:62 --Progress(%):98.58-- Loss:0.16 -- Acc:94.54
# Epoch:62 --Val Loss:0.54 -- Acc:83.94
#
# Epoch: 63
# Epoch:63 --Progress(%):24.43-- Loss:0.14 -- Acc:95.04
# Epoch:63 --Progress(%):49.15-- Loss:0.14 -- Acc:95.10
# Epoch:63 --Progress(%):73.86-- Loss:0.15 -- Acc:95.09
# Epoch:63 --Progress(%):98.58-- Loss:0.15 -- Acc:94.94
# Epoch:63 --Val Loss:0.50 -- Acc:85.30
#
# Epoch: 64
# Epoch:64 --Progress(%):24.43-- Loss:0.14 -- Acc:95.22
# Epoch:64 --Progress(%):49.15-- Loss:0.15 -- Acc:94.97
# Epoch:64 --Progress(%):73.86-- Loss:0.15 -- Acc:94.80
# Epoch:64 --Progress(%):98.58-- Loss:0.16 -- Acc:94.75
# Epoch:64 --Val Loss:0.48 -- Acc:85.06
#
# Epoch: 65
# Epoch:65 --Progress(%):24.43-- Loss:0.14 -- Acc:95.13
# Epoch:65 --Progress(%):49.15-- Loss:0.15 -- Acc:95.05
# Epoch:65 --Progress(%):73.86-- Loss:0.15 -- Acc:95.03
# Epoch:65 --Progress(%):98.58-- Loss:0.15 -- Acc:94.97
# Epoch:65 --Val Loss:0.50 -- Acc:85.28
#
# Epoch: 66
# Epoch:66 --Progress(%):24.43-- Loss:0.13 -- Acc:95.60
# Epoch:66 --Progress(%):49.15-- Loss:0.14 -- Acc:95.35
# Epoch:66 --Progress(%):73.86-- Loss:0.14 -- Acc:95.25
# Epoch:66 --Progress(%):98.58-- Loss:0.14 -- Acc:95.05
# Epoch:66 --Val Loss:0.54 -- Acc:84.44
#
# Epoch: 67
# Epoch:67 --Progress(%):24.43-- Loss:0.12 -- Acc:96.00
# Epoch:67 --Progress(%):49.15-- Loss:0.13 -- Acc:95.70
# Epoch:67 --Progress(%):73.86-- Loss:0.14 -- Acc:95.37
# Epoch:67 --Progress(%):98.58-- Loss:0.15 -- Acc:95.04
# Epoch:67 --Val Loss:0.54 -- Acc:83.72
#
# Epoch: 68
# Epoch:68 --Progress(%):24.43-- Loss:0.13 -- Acc:95.43
# Epoch:68 --Progress(%):49.15-- Loss:0.14 -- Acc:95.29
# Epoch:68 --Progress(%):73.86-- Loss:0.14 -- Acc:95.12
# Epoch:68 --Progress(%):98.58-- Loss:0.14 -- Acc:94.96
# Epoch:68 --Val Loss:0.50 -- Acc:85.58
#
# Epoch: 69
# Epoch:69 --Progress(%):24.43-- Loss:0.13 -- Acc:96.02
# Epoch:69 --Progress(%):49.15-- Loss:0.13 -- Acc:95.68
# Epoch:69 --Progress(%):73.86-- Loss:0.14 -- Acc:95.41
# Epoch:69 --Progress(%):98.58-- Loss:0.14 -- Acc:95.32
# Epoch:69 --Val Loss:0.51 -- Acc:84.34
#
# Epoch: 70
# Epoch:70 --Progress(%):24.43-- Loss:0.12 -- Acc:96.06
# Epoch:70 --Progress(%):49.15-- Loss:0.12 -- Acc:95.91
# Epoch:70 --Progress(%):73.86-- Loss:0.13 -- Acc:95.69
# Epoch:70 --Progress(%):98.58-- Loss:0.13 -- Acc:95.51
# Epoch:70 --Val Loss:0.58 -- Acc:83.14
#
# Epoch: 71
# Epoch:71 --Progress(%):24.43-- Loss:0.13 -- Acc:95.33
# Epoch:71 --Progress(%):49.15-- Loss:0.13 -- Acc:95.52
# Epoch:71 --Progress(%):73.86-- Loss:0.13 -- Acc:95.47
# Epoch:71 --Progress(%):98.58-- Loss:0.13 -- Acc:95.38
# Epoch:71 --Val Loss:0.55 -- Acc:85.00
#
# Epoch: 72
# Epoch:72 --Progress(%):24.43-- Loss:0.13 -- Acc:95.63
# Epoch:72 --Progress(%):49.15-- Loss:0.13 -- Acc:95.66
# Epoch:72 --Progress(%):73.86-- Loss:0.13 -- Acc:95.61
# Epoch:72 --Progress(%):98.58-- Loss:0.13 -- Acc:95.55
# Epoch:72 --Val Loss:0.57 -- Acc:84.16
#
# Epoch: 73
# Epoch:73 --Progress(%):24.43-- Loss:0.13 -- Acc:95.73
# Epoch:73 --Progress(%):49.15-- Loss:0.13 -- Acc:95.67
# Epoch:73 --Progress(%):73.86-- Loss:0.13 -- Acc:95.68
# Epoch:73 --Progress(%):98.58-- Loss:0.13 -- Acc:95.52
# Epoch:73 --Val Loss:0.54 -- Acc:85.18
#
# Epoch: 74
# Epoch:74 --Progress(%):24.43-- Loss:0.12 -- Acc:95.84
# Epoch:74 --Progress(%):49.15-- Loss:0.12 -- Acc:95.93
# Epoch:74 --Progress(%):73.86-- Loss:0.13 -- Acc:95.73
# Epoch:74 --Progress(%):98.58-- Loss:0.13 -- Acc:95.52
# Epoch:74 --Val Loss:0.46 -- Acc:86.74
# Saving the best model.
#
# Epoch: 75
# Epoch:75 --Progress(%):24.43-- Loss:0.11 -- Acc:96.35
# Epoch:75 --Progress(%):49.15-- Loss:0.11 -- Acc:96.30
# Epoch:75 --Progress(%):73.86-- Loss:0.11 -- Acc:96.22
# Epoch:75 --Progress(%):98.58-- Loss:0.12 -- Acc:95.91
# Epoch:75 --Val Loss:0.50 -- Acc:84.98
#
# Epoch: 76
# Epoch:76 --Progress(%):24.43-- Loss:0.11 -- Acc:96.35
# Epoch:76 --Progress(%):49.15-- Loss:0.12 -- Acc:96.05
# Epoch:76 --Progress(%):73.86-- Loss:0.13 -- Acc:95.84
# Epoch:76 --Progress(%):98.58-- Loss:0.13 -- Acc:95.71
# Epoch:76 --Val Loss:0.49 -- Acc:85.70
#
# Epoch: 77
# Epoch:77 --Progress(%):24.43-- Loss:0.12 -- Acc:96.12
# Epoch:77 --Progress(%):49.15-- Loss:0.12 -- Acc:96.11
# Epoch:77 --Progress(%):73.86-- Loss:0.12 -- Acc:96.08
# Epoch:77 --Progress(%):98.58-- Loss:0.12 -- Acc:95.92
# Epoch:77 --Val Loss:0.52 -- Acc:85.36
#
# Epoch: 78
# Epoch:78 --Progress(%):24.43-- Loss:0.11 -- Acc:96.19
# Epoch:78 --Progress(%):49.15-- Loss:0.11 -- Acc:96.18
# Epoch:78 --Progress(%):73.86-- Loss:0.12 -- Acc:96.03
# Epoch:78 --Progress(%):98.58-- Loss:0.12 -- Acc:95.93
# Epoch:78 --Val Loss:0.54 -- Acc:84.72
#
# Epoch: 79
# Epoch:79 --Progress(%):24.43-- Loss:0.10 -- Acc:96.62
# Epoch:79 --Progress(%):49.15-- Loss:0.11 -- Acc:96.49
# Epoch:79 --Progress(%):73.86-- Loss:0.11 -- Acc:96.30
# Epoch:79 --Progress(%):98.58-- Loss:0.11 -- Acc:96.25
# Epoch:79 --Val Loss:0.48 -- Acc:85.70
#
# Epoch: 80
# Epoch:80 --Progress(%):24.43-- Loss:0.11 -- Acc:96.13
# Epoch:80 --Progress(%):49.15-- Loss:0.11 -- Acc:96.21
# Epoch:80 --Progress(%):73.86-- Loss:0.11 -- Acc:96.19
# Epoch:80 --Progress(%):98.58-- Loss:0.11 -- Acc:96.05
# Epoch:80 --Val Loss:0.56 -- Acc:84.88
#
# Epoch: 81
# Epoch:81 --Progress(%):24.43-- Loss:0.11 -- Acc:96.25
# Epoch:81 --Progress(%):49.15-- Loss:0.11 -- Acc:96.23
# Epoch:81 --Progress(%):73.86-- Loss:0.11 -- Acc:96.18
# Epoch:81 --Progress(%):98.58-- Loss:0.11 -- Acc:96.14
# Epoch:81 --Val Loss:0.47 -- Acc:85.82
#
# Epoch: 82
# Epoch:82 --Progress(%):24.43-- Loss:0.10 -- Acc:96.55
# Epoch:82 --Progress(%):49.15-- Loss:0.10 -- Acc:96.41
# Epoch:82 --Progress(%):73.86-- Loss:0.11 -- Acc:96.37
# Epoch:82 --Progress(%):98.58-- Loss:0.11 -- Acc:96.26
# Epoch:82 --Val Loss:0.51 -- Acc:85.36
#
# Epoch: 83
# Epoch:83 --Progress(%):24.43-- Loss:0.10 -- Acc:96.72
# Epoch:83 --Progress(%):49.15-- Loss:0.11 -- Acc:96.40
# Epoch:83 --Progress(%):73.86-- Loss:0.11 -- Acc:96.28
# Epoch:83 --Progress(%):98.58-- Loss:0.11 -- Acc:96.22
# Epoch:83 --Val Loss:0.48 -- Acc:86.44
#
# Epoch: 84
# Epoch:84 --Progress(%):24.43-- Loss:0.09 -- Acc:96.89
# Epoch:84 --Progress(%):49.15-- Loss:0.10 -- Acc:96.70
# Epoch:84 --Progress(%):73.86-- Loss:0.10 -- Acc:96.68
# Epoch:84 --Progress(%):98.58-- Loss:0.10 -- Acc:96.57
# Epoch:84 --Val Loss:0.50 -- Acc:85.98
#
# Epoch: 85
# Epoch:85 --Progress(%):24.43-- Loss:0.10 -- Acc:96.70
# Epoch:85 --Progress(%):49.15-- Loss:0.10 -- Acc:96.72
# Epoch:85 --Progress(%):73.86-- Loss:0.10 -- Acc:96.78
# Epoch:85 --Progress(%):98.58-- Loss:0.10 -- Acc:96.66
# Epoch:85 --Val Loss:0.50 -- Acc:86.00
#
# Epoch: 86
# Epoch:86 --Progress(%):24.43-- Loss:0.10 -- Acc:96.87
# Epoch:86 --Progress(%):49.15-- Loss:0.10 -- Acc:96.76
# Epoch:86 --Progress(%):73.86-- Loss:0.10 -- Acc:96.74
# Epoch:86 --Progress(%):98.58-- Loss:0.10 -- Acc:96.54
# Epoch:86 --Val Loss:0.54 -- Acc:84.90
#
# Epoch: 87
# Epoch:87 --Progress(%):24.43-- Loss:0.10 -- Acc:96.54
# Epoch:87 --Progress(%):49.15-- Loss:0.10 -- Acc:96.75
# Epoch:87 --Progress(%):73.86-- Loss:0.10 -- Acc:96.60
# Epoch:87 --Progress(%):98.58-- Loss:0.10 -- Acc:96.58
# Epoch:87 --Val Loss:0.54 -- Acc:84.86
#
# Epoch: 88
# Epoch:88 --Progress(%):24.43-- Loss:0.09 -- Acc:96.96
# Epoch:88 --Progress(%):49.15-- Loss:0.10 -- Acc:96.86
# Epoch:88 --Progress(%):73.86-- Loss:0.09 -- Acc:96.90
# Epoch:88 --Progress(%):98.58-- Loss:0.10 -- Acc:96.86
# Epoch:88 --Val Loss:0.51 -- Acc:85.20
#
# Epoch: 89
# Epoch:89 --Progress(%):24.43-- Loss:0.09 -- Acc:97.39
# Epoch:89 --Progress(%):49.15-- Loss:0.09 -- Acc:97.24
# Epoch:89 --Progress(%):73.86-- Loss:0.09 -- Acc:96.89
# Epoch:89 --Progress(%):98.58-- Loss:0.10 -- Acc:96.72
# Epoch:89 --Val Loss:0.47 -- Acc:85.74
#
# Epoch: 90
# Epoch:90 --Progress(%):24.43-- Loss:0.08 -- Acc:97.43
# Epoch:90 --Progress(%):49.15-- Loss:0.09 -- Acc:97.16
# Epoch:90 --Progress(%):73.86-- Loss:0.09 -- Acc:96.93
# Epoch:90 --Progress(%):98.58-- Loss:0.09 -- Acc:96.89
# Epoch:90 --Val Loss:0.52 -- Acc:86.30
#
# Epoch: 91
# Epoch:91 --Progress(%):24.43-- Loss:0.08 -- Acc:97.29
# Epoch:91 --Progress(%):49.15-- Loss:0.08 -- Acc:97.38
# Epoch:91 --Progress(%):73.86-- Loss:0.09 -- Acc:97.17
# Epoch:91 --Progress(%):98.58-- Loss:0.09 -- Acc:97.07
# Epoch:91 --Val Loss:0.51 -- Acc:85.40
#
# Epoch: 92
# Epoch:92 --Progress(%):24.43-- Loss:0.09 -- Acc:97.21
# Epoch:92 --Progress(%):49.15-- Loss:0.09 -- Acc:96.98
# Epoch:92 --Progress(%):73.86-- Loss:0.09 -- Acc:96.83
# Epoch:92 --Progress(%):98.58-- Loss:0.09 -- Acc:96.85
# Epoch:92 --Val Loss:0.53 -- Acc:85.82
#
# Epoch: 93
# Epoch:93 --Progress(%):24.43-- Loss:0.08 -- Acc:97.42
# Epoch:93 --Progress(%):49.15-- Loss:0.08 -- Acc:97.21
# Epoch:93 --Progress(%):73.86-- Loss:0.09 -- Acc:97.08
# Epoch:93 --Progress(%):98.58-- Loss:0.09 -- Acc:97.01
# Epoch:93 --Val Loss:0.52 -- Acc:85.42
#
# Epoch: 94
# Epoch:94 --Progress(%):24.43-- Loss:0.08 -- Acc:97.18
# Epoch:94 --Progress(%):49.15-- Loss:0.08 -- Acc:97.37
# Epoch:94 --Progress(%):73.86-- Loss:0.08 -- Acc:97.25
# Epoch:94 --Progress(%):98.58-- Loss:0.08 -- Acc:97.14
# Epoch:94 --Val Loss:0.51 -- Acc:85.72
#
# Epoch: 95
# Epoch:95 --Progress(%):24.43-- Loss:0.07 -- Acc:97.67
# Epoch:95 --Progress(%):49.15-- Loss:0.08 -- Acc:97.32
# Epoch:95 --Progress(%):73.86-- Loss:0.08 -- Acc:97.37
# Epoch:95 --Progress(%):98.58-- Loss:0.08 -- Acc:97.26
# Epoch:95 --Val Loss:0.49 -- Acc:86.08
#
# Epoch: 96
# Epoch:96 --Progress(%):24.43-- Loss:0.08 -- Acc:97.61
# Epoch:96 --Progress(%):49.15-- Loss:0.08 -- Acc:97.55
# Epoch:96 --Progress(%):73.86-- Loss:0.08 -- Acc:97.43
# Epoch:96 --Progress(%):98.58-- Loss:0.08 -- Acc:97.31
# Epoch:96 --Val Loss:0.52 -- Acc:85.46
#
# Epoch: 97
# Epoch:97 --Progress(%):24.43-- Loss:0.08 -- Acc:97.53
# Epoch:97 --Progress(%):49.15-- Loss:0.08 -- Acc:97.52
# Epoch:97 --Progress(%):73.86-- Loss:0.08 -- Acc:97.40
# Epoch:97 --Progress(%):98.58-- Loss:0.08 -- Acc:97.29
# Epoch:97 --Val Loss:0.53 -- Acc:85.80
#
# Epoch: 98
# Epoch:98 --Progress(%):24.43-- Loss:0.08 -- Acc:97.43
# Epoch:98 --Progress(%):49.15-- Loss:0.07 -- Acc:97.61
# Epoch:98 --Progress(%):73.86-- Loss:0.08 -- Acc:97.47
# Epoch:98 --Progress(%):98.58-- Loss:0.08 -- Acc:97.44
# Epoch:98 --Val Loss:0.53 -- Acc:85.46
#
# Epoch: 99
# Epoch:99 --Progress(%):24.43-- Loss:0.06 -- Acc:98.11
# Epoch:99 --Progress(%):49.15-- Loss:0.06 -- Acc:98.02
# Epoch:99 --Progress(%):73.86-- Loss:0.07 -- Acc:97.80
# Epoch:99 --Progress(%):98.58-- Loss:0.07 -- Acc:97.58
# Epoch:99 --Val Loss:0.54 -- Acc:85.30
# ***** Begin testing *****
# Epoch:99 --Test Loss:0.49 -- Acc:87.27
